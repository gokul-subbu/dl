# %%
# %matplotlib inline

# %%
from PIL import Image
from pathlib import Path
import os
import matplotlib.pyplot as plt
Path.ls= lambda x:[i.name for i in os.scandir(x)]

# %%
path=Path(r'D:\datasets')

# %%
path.ls()
# Out:
# ['air-traffic',
#  'ashrae',
#  'buldozers',
#  'cat-in-the-dat',
#  'data',
#  'loan',
#  'ner',
#  'new_datasets',
#  'rossman',
#  'small_datasets',
#  'sql',
#  'unsorted']

# %%
path=Path(r'D:\git\dl\data\test_bench')
path.ls()
# Out:
# ['img (1).jpg',
#  'img (2).jpg',
#  'img (3).jpg',
#  'img (4).jpg',
#  'img (5).jpg',
#  'img (6).jpg',
#  'img (7).jpg']

# %%
l=list(path.ls())

# %%
img=Image.open(path/'img (1).jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=875x1080 at 0x238B7CE3970>
