# %%
# %matplotlib inline

# %%
from pathlib import Path
import pandas as pd
import numpy as np
from sklearn.linear_model import Lasso
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from feature_engine import missing_data_imputers as mdi
from feature_engine import discretisers as dsc
from feature_engine import categorical_encoders as ce
import matplotlib.pyplot as plt

pd.pandas.set_option('display.max_columns', None)
Path.ls=lambda x: list(x.iterdir())

# %%
path_data=Path(r'D:\datasets\new_datasets')
list(path_data.iterdir())
# Out:
# [WindowsPath('D:/datasets/new_datasets/caterpillar-tube-pricing'),
#  WindowsPath('D:/datasets/new_datasets/costa-rican-household-poverty-prediction'),
#  WindowsPath('D:/datasets/new_datasets/flavours-of-physics-kernels-only'),
#  WindowsPath('D:/datasets/new_datasets/higgs-boson'),
#  WindowsPath('D:/datasets/new_datasets/leaf-classification'),
#  WindowsPath('D:/datasets/new_datasets/mercedes-benz-greener-manufacturing'),
#  WindowsPath('D:/datasets/new_datasets/msk-redefining-cancer-treatment'),
#  WindowsPath('D:/datasets/new_datasets/MusicHackathon'),
#  WindowsPath('D:/datasets/new_datasets/nomad2018-predict-transparent-conductors'),
#  WindowsPath('D:/datasets/new_datasets/porto-seguro-safe-driver-prediction'),
#  WindowsPath('D:/datasets/new_datasets/predict-west-nile-virus'),
#  WindowsPath('D:/datasets/new_datasets/predict-who-is-more-influential-in-a-social-network'),
#  WindowsPath('D:/datasets/new_datasets/random-acts-of-pizza'),
#  WindowsPath('D:/datasets/new_datasets/recruit-restaurant-visitor-forecasting'),
#  WindowsPath('D:/datasets/new_datasets/sberbank-russian-housing-market'),
#  WindowsPath('D:/datasets/new_datasets/spooky-author-identification'),
#  WindowsPath('D:/datasets/new_datasets/whats-cooking')]

# %%
path_house=path_data/'sberbank-russian-housing-market'
list(path_house.iterdir())
# Out:
# [WindowsPath('D:/datasets/new_datasets/sberbank-russian-housing-market/data_dictionary.txt'),
#  WindowsPath('D:/datasets/new_datasets/sberbank-russian-housing-market/macro.csv.zip'),
#  WindowsPath('D:/datasets/new_datasets/sberbank-russian-housing-market/New folder'),
#  WindowsPath('D:/datasets/new_datasets/sberbank-russian-housing-market/sample_submission.csv.zip'),
#  WindowsPath('D:/datasets/new_datasets/sberbank-russian-housing-market/test.csv'),
#  WindowsPath('D:/datasets/new_datasets/sberbank-russian-housing-market/train.csv'),
#  WindowsPath('D:/datasets/new_datasets/sberbank-russian-housing-market/__MACOSX')]

# %%
path_house_train=path_house/'train.csv'
path_house_test=path_house/'test.csv'

# %%
df_train=pd.read_csv(path_house_train, index_col='id', parse_dates=['timestamp'], infer_datetime_format=True)
df_train.head()
# Out:
#     timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# id
# 1  2011-08-20       43     27.0    4.0        NaN       NaN         NaN
# 2  2011-08-23       34     19.0    3.0        NaN       NaN         NaN
# 3  2011-08-27       43     29.0    2.0        NaN       NaN         NaN
# 4  2011-09-01       89     50.0    9.0        NaN       NaN         NaN
# 5  2011-09-05       77     77.0    4.0        NaN       NaN         NaN
#
#     num_room  kitch_sq  state product_type           sub_area        area_m  \
# id
# 1        NaN       NaN    NaN   Investment           Bibirevo  6.407578e+06
# 2        NaN       NaN    NaN   Investment  Nagatinskij Zaton  9.589337e+06
# 3        NaN       NaN    NaN   Investment     Tekstil'shhiki  4.808270e+06
# 4        NaN       NaN    NaN   Investment             Mitino  1.258354e+07
# 5        NaN       NaN    NaN   Investment          Basmannoe  8.398461e+06
#
#     raion_popul  green_zone_part  indust_part  children_preschool  \
# id
# 1        155572         0.189727     0.000070                9576
# 2        115352         0.372602     0.049637                6880
# 3        101708         0.112560     0.118537                5879
# 4        178473         0.194703     0.069753               13087
# 5        108171         0.015234     0.037316                5706
#
#     preschool_quota  preschool_education_centers_raion  children_school  \
# id
# 1            5001.0                                  5            10309
# 2            3119.0                                  5             7759
# 3            1463.0                                  4             6207
# 4            6839.0                                  9            13670
# 5            3240.0                                  7             6748
#
#     school_quota  school_education_centers_raion  \
# id
# 1        11065.0                               5
# 2         6237.0                               8
# 3         5580.0                               7
# 4        17063.0                              10
# 5         7770.0                               9
#
#     school_education_centers_top_20_raion  hospital_beds_raion  \
# id
# 1                                       0                240.0
# 2                                       0                229.0
# 3                                       0               1183.0
# 4                                       0                  NaN
# 5                                       0                562.0
#
#     healthcare_centers_raion  university_top_20_raion  sport_objects_raion  \
# id
# 1                          1                        0                    7
# 2                          1                        0                    6
# 3                          1                        0                    5
# 4                          1                        0                   17
# 5                          4                        2                   25
#
#     additional_education_raion culture_objects_top_25  \
# id
# 1                            3                     no
# 2                            1                    yes
# 3                            1                     no
# 4                            6                     no
# 5                            2                     no
#
#     culture_objects_top_25_raion  shopping_centers_raion  office_raion  \
# id
# 1                              0                      16             1
# 2                              1                       3             0
# 3                              0                       0             1
# 4                              0                      11             4
# 5                              0                      10            93
#
#    thermal_power_plant_raion incineration_raion oil_chemistry_raion  \
# id
# 1                         no                 no                  no
# 2                         no                 no                  no
# 3                         no                 no                  no
# 4                         no                 no                  no
# 5                         no                 no                  no
#
#    radiation_raion railroad_terminal_raion big_market_raion  \
# id
# 1               no                      no               no
# 2               no                      no               no
# 3              yes                      no               no
# 4               no                      no               no
# 5              yes                     yes               no
#
#    nuclear_reactor_raion detention_facility_raion  full_all  male_f  female_f  \
# id
# 1                     no                       no     86206   40477     45729
# 2                     no                       no     76284   34200     42084
# 3                     no                       no    101982   46076     55906
# 4                     no                       no     21155    9828     11327
# 5                     no                       no     28179   13522     14657
#
#     young_all  young_male  young_female  work_all  work_male  work_female  \
# id
# 1       21154       11007         10147     98207      52277        45930
# 2       15727        7925          7802     70194      35622        34572
# 3       13028        6835          6193     63388      31813        31575
# 4       28563       14680         13883    120381      60040        60341
# 5       13368        7159          6209     68043      34236        33807
#
#     ekder_all  ekder_male  ekder_female  0_6_all  0_6_male  0_6_female  \
# id
# 1       36211       10580         25631     9576      4899        4677
# 2       29431        9266         20165     6880      3466        3414
# 3       25292        7609         17683     5879      3095        2784
# 4       29529        9083         20446    13087      6645        6442
# 5       26760        8563         18197     5706      2982        2724
#
#     7_14_all  7_14_male  7_14_female  0_17_all  0_17_male  0_17_female  \
# id
# 1      10309       5463         4846     23603      12286        11317
# 2       7759       3909         3850     17700       8998         8702
# 3       6207       3269         2938     14884       7821         7063
# 4      13670       7126         6544     32063      16513        15550
# 5       6748       3664         3084     15237       8113         7124
#
#     16_29_all  16_29_male  16_29_female  0_13_all  0_13_male  0_13_female  \
# id
# 1       17508        9425          8083     18654       9709         8945
# 2       15164        7571          7593     13729       6929         6800
# 3       19401        9045         10356     11252       5916         5336
# 4        3292        1450          1842     24934      12782        12152
# 5        5164        2583          2581     11631       6223         5408
#
#     raion_build_count_with_material_info  build_count_block  build_count_wood  \
# id
# 1                                  211.0               25.0               0.0
# 2                                  245.0               83.0               1.0
# 3                                  330.0               59.0               0.0
# 4                                  458.0                9.0              51.0
# 5                                  746.0               48.0               0.0
#
#     build_count_frame  build_count_brick  build_count_monolith  \
# id
# 1                 0.0                0.0                   2.0
# 2                 0.0               67.0                   4.0
# 3                 0.0              206.0                   4.0
# 4                12.0              124.0                  50.0
# 5                 0.0              643.0                  16.0
#
#     build_count_panel  build_count_foam  build_count_slag  build_count_mix  \
# id
# 1               184.0               0.0               0.0              0.0
# 2                90.0               0.0               0.0              0.0
# 3                60.0               0.0               1.0              0.0
# 4               201.0               0.0               9.0              2.0
# 5                35.0               0.0               3.0              1.0
#
#     raion_build_count_with_builddate_info  build_count_before_1920  \
# id
# 1                                   211.0                      0.0
# 2                                   244.0                      1.0
# 3                                   330.0                      1.0
# 4                                   459.0                     13.0
# 5                                   746.0                    371.0
#
#     build_count_1921-1945  build_count_1946-1970  build_count_1971-1995  \
# id
# 1                     0.0                    0.0                  206.0
# 2                     1.0                  143.0                   84.0
# 3                     0.0                  246.0                   63.0
# 4                    24.0                   40.0                  130.0
# 5                   114.0                  146.0                   62.0
#
#     build_count_after_1995  ID_metro  metro_min_avto  metro_km_avto  \
# id
# 1                      5.0         1        2.590241       1.131260
# 2                     15.0         2        0.936700       0.647337
# 3                     20.0         3        2.120999       1.637996
# 4                    252.0         4        1.489049       0.984537
# 5                     53.0         5        1.257186       0.876620
#
#     metro_min_walk  metro_km_walk  kindergarten_km  school_km   park_km  \
# id
# 1        13.575119       1.131260         0.145700   0.177975  2.158587
# 2         7.620630       0.635053         0.147754   0.273345  0.550690
# 3        17.351515       1.445960         0.049102   0.158072  0.374848
# 4        11.565624       0.963802         0.179441   0.236455  0.078090
# 5         8.266305       0.688859         0.247901   0.376838  0.258289
#
#     green_zone_km  industrial_km  water_treatment_km  cemetery_km  \
# id
# 1        0.600973       1.080934           23.683460     1.804127
# 2        0.065321       0.966479            1.317476     4.655004
# 3        0.453172       0.939275            4.912660     3.381083
# 4        0.106125       0.451173           15.623710     2.017080
# 5        0.236214       0.392871           10.683540     2.936581
#
#     incineration_km  railroad_station_walk_km  railroad_station_walk_min  \
# id
# 1          3.633334                  5.419893                  65.038716
# 2          8.648587                  3.411993                  40.943917
# 3         11.996480                  1.277658                  15.331896
# 4         14.317640                  4.291432                  51.497190
# 5         11.903910                  0.853960                  10.247521
#
#     ID_railroad_station_walk  railroad_station_avto_km  \
# id
# 1                        1.0                  5.419893
# 2                        2.0                  3.641773
# 3                        3.0                  1.277658
# 4                        4.0                  3.816045
# 5                        5.0                  1.595898
#
#     railroad_station_avto_min  ID_railroad_station_avto  \
# id
# 1                    6.905893                         1
# 2                    4.679745                         2
# 3                    1.701420                         3
# 4                    5.271136                         4
# 5                    2.156284                       113
#
#     public_transport_station_km  public_transport_station_min_walk  water_km  \
# id
# 1                      0.274985                           3.299822  0.992631
# 2                      0.065263                           0.783160  0.698081
# 3                      0.328756                           3.945073  0.468265
# 4                      0.131597                           1.579164  1.200336
# 5                      0.071480                           0.857764  0.820294
#
#    water_1line    mkad_km     ttk_km  sadovoe_km  bulvar_ring_km  kremlin_km  \
# id
# 1           no   1.422391  10.918587   13.100618       13.675657   15.156211
# 2           no   9.503405   3.103996    6.444333        8.132640    8.698054
# 3           no   5.604800   2.927487    6.963403        8.054252    9.067885
# 4           no   2.677824  14.606501   17.457198       18.309433   19.487005
# 5           no  11.616653   1.721834    0.046810        0.787593    2.578671
#
#     big_road1_km  ID_big_road1 big_road1_1line  big_road2_km  ID_big_road2  \
# id
# 1       1.422391             1              no      3.830951             5
# 2       2.887377             2              no      3.103996             4
# 3       0.647250             3              no      2.927487             4
# 4       2.677824             1              no      2.780449            17
# 5       1.721834             4              no      3.133531            10
#
#     railroad_km railroad_1line  zd_vokzaly_avto_km  ID_railroad_terminal  \
# id
# 1      1.305159             no           14.231961                   101
# 2      0.694536             no            9.242586                    32
# 3      0.700691             no            9.540544                     5
# 4      1.999265             no           17.478380                    83
# 5      0.084113            yes            1.595898                   113
#
#     bus_terminal_avto_km  ID_bus_terminal  oil_chemistry_km  \
# id
# 1              24.292406                1         18.152338
# 2               5.706113                2          9.034642
# 3               6.710302                3          5.777394
# 4               6.734618                1         27.667863
# 5               1.423428                4          6.515857
#
#     nuclear_reactor_km  radiation_km  power_transmission_line_km  \
# id
# 1             5.718519      1.210027                    1.062513
# 2             3.489954      2.724295                    1.246149
# 3             7.506612      0.772216                    1.602183
# 4             9.522538      6.348716                    1.767612
# 5             8.671016      1.638318                    3.632640
#
#     thermal_power_plant_km     ts_km  big_market_km  market_shop_km  \
# id
# 1                 5.814135  4.308127      10.814172        1.676258
# 2                 3.419574  0.725560       6.910568        3.424716
# 3                 3.682455  3.562188       5.752368        1.375443
# 4                11.178333  0.583025      27.892717        0.811275
# 5                 4.587917  2.609420       9.155057        1.969738
#
#     fitness_km  swim_pool_km  ice_rink_km  stadium_km  basketball_km  \
# id
# 1     0.485841      3.065047     1.107594    8.148591       3.516513
# 2     0.668364      2.000154     8.972823    6.127073       1.161579
# 3     0.733101      1.239304     1.978517    0.767569       1.952771
# 4     0.623484      1.950317     6.483172    7.385521       4.923843
# 5     0.220288      2.544696     3.975401    3.610754       0.307915
#
#     hospice_morgue_km  detention_facility_km  public_healthcare_km  \
# id
# 1            2.392353               4.248036              0.974743
# 2            2.543747              12.649879              1.477723
# 3            0.621357               7.682303              0.097144
# 4            3.549558               8.789894              2.163735
# 5            1.864637               3.779781              1.121703
#
#     university_km  workplaces_km  shopping_centers_km  office_km  \
# id
# 1        6.715026       0.884350             0.648488   0.637189
# 2        1.852560       0.686252             0.519311   0.688796
# 3        0.841254       1.510089             1.486533   1.543049
# 4       10.903161       0.622272             0.599914   0.934273
# 5        0.991683       0.892668             0.429052   0.077901
#
#     additional_education_km  preschool_km  big_church_km  church_synagogue_km  \
# id
# 1                  0.947962      0.177975       0.625783             0.628187
# 2                  1.072315      0.273345       0.967821             0.471447
# 3                  0.391957      0.158072       3.178751             0.755946
# 4                  0.892674      0.236455       1.031777             1.561505
# 5                  0.810801      0.376838       0.378756             0.121681
#
#     mosque_km  theater_km  museum_km  exhibition_km  catering_km    ecology  \
# id
# 1    3.932040   14.053047   7.389498       7.023705     0.516838       good
# 2    4.841544    6.829889   0.709260       2.358840     0.230287  excellent
# 3    7.922152    4.273200   3.156423       4.958214     0.190462       poor
# 4   15.300449   16.990677  16.041521       5.029696     0.465820       good
# 5    2.584370    1.112486   1.800125       1.339652     0.026102  excellent
#
#     green_part_500  prom_part_500  office_count_500  office_sqm_500  \
# id
# 1             0.00           0.00                 0               0
# 2            25.14           0.00                 0               0
# 3             1.67           0.00                 0               0
# 4            17.36           0.57                 0               0
# 5             3.56           4.44                15          293699
#
#     trc_count_500  trc_sqm_500  cafe_count_500  cafe_sum_500_min_price_avg  \
# id
# 1               0            0               0                         NaN
# 2               0            0               5                      860.00
# 3               0            0               3                      666.67
# 4               0            0               2                     1000.00
# 5               1        45000              48                      702.22
#
#     cafe_sum_500_max_price_avg  cafe_avg_price_500  cafe_count_500_na_price  \
# id
# 1                          NaN                 NaN                        0
# 2                      1500.00             1180.00                        0
# 3                      1166.67              916.67                        0
# 4                      1500.00             1250.00                        0
# 5                      1166.67              934.44                        3
#
#     cafe_count_500_price_500  cafe_count_500_price_1000  \
# id
# 1                          0                          0
# 2                          1                          3
# 3                          0                          2
# 4                          0                          0
# 5                         17                         10
#
#     cafe_count_500_price_1500  cafe_count_500_price_2500  \
# id
# 1                           0                          0
# 2                           0                          0
# 3                           1                          0
# 4                           2                          0
# 5                          11                          7
#
#     cafe_count_500_price_4000  cafe_count_500_price_high  \
# id
# 1                           0                          0
# 2                           1                          0
# 3                           0                          0
# 4                           0                          0
# 5                           0                          0
#
#     big_church_count_500  church_count_500  mosque_count_500  \
# id
# 1                      0                 0                 0
# 2                      0                 1                 0
# 3                      0                 0                 0
# 4                      0                 0                 0
# 5                      1                 4                 0
#
#     leisure_count_500  sport_count_500  market_count_500  green_part_1000  \
# id
# 1                   0                1                 0             7.36
# 2                   0                0                 0            26.66
# 3                   0                0                 0             4.99
# 4                   0                0                 0            19.25
# 5                   2                3                 0             3.34
#
#     prom_part_1000  office_count_1000  office_sqm_1000  trc_count_1000  \
# id
# 1             0.00                  1            30500               3
# 2             0.07                  2            86600               5
# 3             0.29                  0                0               0
# 4            10.35                  1            11000               6
# 5             8.29                 46           420952               3
#
#     trc_sqm_1000  cafe_count_1000  cafe_sum_1000_min_price_avg  \
# id
# 1          55600               19                       527.78
# 2          94065               13                       615.38
# 3              0                9                       642.86
# 4          80780               12                       658.33
# 5         158200              153                       763.45
#
#     cafe_sum_1000_max_price_avg  cafe_avg_price_1000  \
# id
# 1                        888.89               708.33
# 2                       1076.92               846.15
# 3                       1142.86               892.86
# 4                       1083.33               870.83
# 5                       1272.41              1017.93
#
#     cafe_count_1000_na_price  cafe_count_1000_price_500  \
# id
# 1                          1                         10
# 2                          0                          5
# 3                          2                          0
# 4                          0                          3
# 5                          8                         39
#
#     cafe_count_1000_price_1000  cafe_count_1000_price_1500  \
# id
# 1                            4                           3
# 2                            6                           1
# 3                            5                           2
# 4                            4                           5
# 5                           45                          39
#
#     cafe_count_1000_price_2500  cafe_count_1000_price_4000  \
# id
# 1                            1                           0
# 2                            0                           1
# 3                            0                           0
# 4                            0                           0
# 5                           19                           2
#
#     cafe_count_1000_price_high  big_church_count_1000  church_count_1000  \
# id
# 1                            0                      1                  2
# 2                            0                      1                  2
# 3                            0                      0                  1
# 4                            0                      0                  0
# 5                            1                      7                 12
#
#     mosque_count_1000  leisure_count_1000  sport_count_1000  \
# id
# 1                   0                   0                 6
# 2                   0                   4                 2
# 3                   0                   0                 5
# 4                   0                   0                 3
# 5                   0                   6                 7
#
#     market_count_1000  green_part_1500  prom_part_1500  office_count_1500  \
# id
# 1                   1            14.27            6.92                  3
# 2                   0            21.53            7.71                  3
# 3                   3             9.92            6.73                  0
# 4                   1            28.38            6.57                  2
# 5                   0             4.12            4.83                 93
#
#     office_sqm_1500  trc_count_1500  trc_sqm_1500  cafe_count_1500  \
# id
# 1             39554               9        171420               34
# 2            102910               7        127065               17
# 3                 0               1          2600               14
# 4             11000               7         89492               23
# 5           1195735               9        445900              272
#
#     cafe_sum_1500_min_price_avg  cafe_sum_1500_max_price_avg  \
# id
# 1                        566.67                       969.70
# 2                        694.12                      1205.88
# 3                        516.67                       916.67
# 4                        673.91                      1130.43
# 5                        766.80                      1272.73
#
#     cafe_avg_price_1500  cafe_count_1500_na_price  cafe_count_1500_price_500  \
# id
# 1                768.18                         1                         14
# 2                950.00                         0                          6
# 3                716.67                         2                          4
# 4                902.17                         0                          5
# 5               1019.76                        19                         70
#
#     cafe_count_1500_price_1000  cafe_count_1500_price_1500  \
# id
# 1                           11                           6
# 2                            7                           1
# 3                            6                           2
# 4                            9                           8
# 5                           74                          72
#
#     cafe_count_1500_price_2500  cafe_count_1500_price_4000  \
# id
# 1                            2                           0
# 2                            2                           1
# 3                            0                           0
# 4                            1                           0
# 5                           30                           6
#
#     cafe_count_1500_price_high  big_church_count_1500  church_count_1500  \
# id
# 1                            0                      1                  2
# 2                            0                      1                  5
# 3                            0                      0                  4
# 4                            0                      1                  0
# 5                            1                     18                 30
#
#     mosque_count_1500  leisure_count_1500  sport_count_1500  \
# id
# 1                   0                   0                 7
# 2                   0                   4                 9
# 3                   0                   0                 6
# 4                   0                   0                 9
# 5                   0                  10                14
#
#     market_count_1500  green_part_2000  prom_part_2000  office_count_2000  \
# id
# 1                   1            11.77           15.97                  9
# 2                   0            22.37           19.25                  4
# 3                   5            12.99           12.75                  4
# 4                   2            32.29            5.73                  2
# 5                   2             4.53            5.02                149
#
#     office_sqm_2000  trc_count_2000  trc_sqm_2000  cafe_count_2000  \
# id
# 1            188854              19       1244891               36
# 2            165510               8        179065               21
# 3            100200               7         52550               24
# 4             11000               7         89492               25
# 5           1625130              17        564843              483
#
#     cafe_sum_2000_min_price_avg  cafe_sum_2000_max_price_avg  \
# id
# 1                        614.29                      1042.86
# 2                        695.24                      1190.48
# 3                        563.64                       977.27
# 4                        660.00                      1120.00
# 5                        765.93                      1269.23
#
#     cafe_avg_price_2000  cafe_count_2000_na_price  cafe_count_2000_price_500  \
# id
# 1                828.57                         1                         15
# 2                942.86                         0                          7
# 3                770.45                         2                          8
# 4                890.00                         0                          5
# 5               1017.58                        28                        130
#
#     cafe_count_2000_price_1000  cafe_count_2000_price_1500  \
# id
# 1                           11                           6
# 2                            8                           3
# 3                            9                           4
# 4                           11                           8
# 5                          129                         131
#
#     cafe_count_2000_price_2500  cafe_count_2000_price_4000  \
# id
# 1                            2                           1
# 2                            2                           1
# 3                            1                           0
# 4                            1                           0
# 5                           50                          14
#
#     cafe_count_2000_price_high  big_church_count_2000  church_count_2000  \
# id
# 1                            0                      1                  2
# 2                            0                      1                  5
# 3                            0                      0                  4
# 4                            0                      1                  1
# 5                            1                     35                 61
#
#     mosque_count_2000  leisure_count_2000  sport_count_2000  \
# id
# 1                   0                   0                10
# 2                   0                   4                11
# 3                   0                   0                 8
# 4                   0                   0                13
# 5                   0                  17                21
#
#     market_count_2000  green_part_3000  prom_part_3000  office_count_3000  \
# id
# 1                   1            11.98           13.55                 12
# 2                   0            18.07           27.32                 12
# 3                   5            12.14           26.46                  8
# 4                   2            20.79            3.57                  4
# 5                   3             5.06            8.62                305
#
#     office_sqm_3000  trc_count_3000  trc_sqm_3000  cafe_count_3000  \
# id
# 1            251554              23       1419204               68
# 2            821986              14        491565               30
# 3            110856               7         52550               41
# 4            167000              12        205756               32
# 5           3420907              60       2296870             1068
#
#     cafe_sum_3000_min_price_avg  cafe_sum_3000_max_price_avg  \
# id
# 1                        639.68                      1079.37
# 2                        631.03                      1086.21
# 3                        697.44                      1192.31
# 4                        718.75                      1218.75
# 5                        853.03                      1410.45
#
#     cafe_avg_price_3000  cafe_count_3000_na_price  cafe_count_3000_price_500  \
# id
# 1                859.52                         5                         21
# 2                858.62                         1                         11
# 3                944.87                         2                          9
# 4                968.75                         0                          5
# 5               1131.74                        63                        266
#
#     cafe_count_3000_price_1000  cafe_count_3000_price_1500  \
# id
# 1                           22                          16
# 2                           11                           4
# 3                           17                           9
# 4                           14                          10
# 5                          267                         262
#
#     cafe_count_3000_price_2500  cafe_count_3000_price_4000  \
# id
# 1                            3                           1
# 2                            2                           1
# 3                            3                           1
# 4                            3                           0
# 5                          149                          57
#
#     cafe_count_3000_price_high  big_church_count_3000  church_count_3000  \
# id
# 1                            0                      2                  4
# 2                            0                      1                  7
# 3                            0                      0                 11
# 4                            0                      1                  2
# 5                            4                     70                121
#
#     mosque_count_3000  leisure_count_3000  sport_count_3000  \
# id
# 1                   0                   0                21
# 2                   0                   6                19
# 3                   0                   0                20
# 4                   0                   0                18
# 5                   1                  40                77
#
#     market_count_3000  green_part_5000  prom_part_5000  office_count_5000  \
# id
# 1                   1            13.09           13.31                 29
# 2                   1            10.26           27.47                 66
# 3                   6            13.69           21.58                 43
# 4                   3            14.18            3.89                  8
# 5                   5             8.38           10.92                689
#
#     office_sqm_5000  trc_count_5000  trc_sqm_5000  cafe_count_5000  \
# id
# 1            807385              52       4036616              152
# 2           2690465              40       2034942              177
# 3           1478160              35       1572990              122
# 4            244166              22        942180               61
# 5           8404624             114       3503058             2283
#
#     cafe_sum_5000_min_price_avg  cafe_sum_5000_max_price_avg  \
# id
# 1                        708.57                      1185.71
# 2                        673.81                      1148.81
# 3                        702.68                      1196.43
# 4                        931.58                      1552.63
# 5                        853.88                      1411.45
#
#     cafe_avg_price_5000  cafe_count_5000_na_price  cafe_count_5000_price_500  \
# id
# 1                947.14                        12                         39
# 2                911.31                         9                         49
# 3                949.55                        10                         29
# 4               1242.11                         4                          7
# 5               1132.66                       143                        566
#
#     cafe_count_5000_price_1000  cafe_count_5000_price_1500  \
# id
# 1                           48                          40
# 2                           65                          36
# 3                           45                          25
# 4                           21                          15
# 5                          578                         552
#
#     cafe_count_5000_price_2500  cafe_count_5000_price_4000  \
# id
# 1                            9                           4
# 2                           15                           3
# 3                           10                           3
# 4                           11                           2
# 5                          319                         108
#
#     cafe_count_5000_price_high  big_church_count_5000  church_count_5000  \
# id
# 1                            0                     13                 22
# 2                            0                     15                 29
# 3                            0                     11                 27
# 4                            1                      4                  4
# 5                           17                    135                236
#
#     mosque_count_5000  leisure_count_5000  sport_count_5000  \
# id
# 1                   1                   0                52
# 2                   1                  10                66
# 3                   0                   4                67
# 4                   0                   0                26
# 5                   2                  91               195
#
#     market_count_5000  price_doc
# id
# 1                   4    5850000
# 2                  14    6000000
# 3                  10    5700000
# 4                   3   13100000
# 5                  14   16331452

# %%
add_datepart(df_train, ['timestamp'])

# %%
discrete = [var for var in df_train.columns if df_train[var].dtype!='O' and var!='price_doc' and df_train[var].nunique()<10]
continuous = [var for var in df_train.columns if df_train[var].dtype!='O' and var!='price_doc' and var not in discrete]
categorical = [var for var in df_train.columns if df_train[var].dtype=='O']

# %%
len(discrete), len(continuous), len(categorical)
# Out:
# (29, 255, 15)

# %%
 def split_val(df:pd.DataFrame, val_pct:float=0.3):
    'returns `df_train` and `df_valid`'
    shuf_idx=np.random.permutation(len(df))
    train_idx, val_idx=shuf_idx[int(val_pct*len(df)):], shuf_idx[:int(val_pct*len(df))]
    return df.iloc[train_idx,:], df.iloc[val_idx,:]
    
def split_dep_col(df:pd.DataFrame, y:str):
    'returns `x` and `y`'
    return df.drop(columns=y), df.loc[:, y]
    
def split_test_val(df:pd.DataFrame, y:str, val_pct:float=0.3):
    ''' df 'pandas datadrame object `y` is the dependent column val_pct:=0.3'
    returns `x_train`, `y_train`, `x_valid`, `y_valid`'''
    df_train, df_val= split_val(df, val_pct)
    return split_dep_col(df_train, y), split_dep_col(df_val, y)

# %%
(x_train, y_train), (x_val, y_val)= split_test_val(df_train, y='price_doc')

# %%
def add_datepart(df:pd.DataFrame, cols:list=None, just_date:bool=True,inplace:bool=True)->pd.DataFrame:
    date_part=['year','month','day','week','dayofweek','weekday','quarter','is_month_start','is_month_end','is_year_end']
    time_part=['time','hour','minute','second']
    for i in cols:
        if not just_date:
            for j in time_part:
                df[f'{i}_{j}']=getattr(df[i].dt,j)
        for j in date_part:
            df[f'{i}_{j}']=getattr(df[i].dt,j)
    df.drop(columns=cols, inplace=True)
    return

# %%
x_train.shape
# Out:
# (21330, 299)

# %%
def check_missing(df:pd.DataFrame, top:int=10):
    return pd.DataFrame(df.isna().mean()).sort_values(by=0, ascending=False)[:top]

# %%
check_missing(x_train[continuous])
# Out:
#                                    0
# hospital_beds_raion         0.474215
# build_year                  0.446976
# cafe_sum_500_min_price_avg  0.439850
# cafe_sum_500_max_price_avg  0.439850
# cafe_avg_price_500          0.439850
# max_floor                   0.314252
# num_room                    0.314252
# kitch_sq                    0.314252
# preschool_quota             0.219081
# school_quota                0.218940

# %%
check_missing(x_train[discrete])
# Out:
#                                  0
# state                     0.446554
# material                  0.314252
# build_count_foam          0.163526
# build_count_mix           0.163526
# mosque_count_1500         0.000000
# timestamp_is_month_end    0.000000
# timestamp_is_month_start  0.000000
# timestamp_quarter         0.000000
# timestamp_weekday         0.000000
# timestamp_dayofweek       0.000000

# %%
check_missing(x_train[categorical])
# Out:
#                              0
# product_type               0.0
# sub_area                   0.0
# culture_objects_top_25     0.0
# thermal_power_plant_raion  0.0
# incineration_raion         0.0
# oil_chemistry_raion        0.0
# radiation_raion            0.0
# railroad_terminal_raion    0.0
# big_market_raion           0.0
# nuclear_reactor_raion      0.0

# %%
x_train.head()
# Out:
#        full_sq  life_sq  floor  max_floor  material  build_year  num_room  \
# id
# 4104        57      NaN   16.0        NaN       NaN         NaN       NaN
# 15625       79      NaN   12.0       17.0       1.0         NaN       3.0
# 1287        63     33.0   16.0        NaN       NaN         NaN       NaN
# 10576       78     78.0   20.0       25.0       1.0      2013.0       3.0
# 575         43     26.0    4.0        NaN       NaN         NaN       NaN
#
#        kitch_sq  state   product_type              sub_area        area_m  \
# id
# 4104        NaN    NaN  OwnerOccupier  Poselenie Vnukovskoe  2.553630e+07
# 15625       0.0    NaN  OwnerOccupier            Nekrasovka  1.139168e+07
# 1287        NaN    NaN     Investment           Cheremushki  5.467178e+06
# 10576       1.0    1.0  OwnerOccupier  Poselenie Moskovskij  4.036700e+07
# 575         NaN    NaN     Investment    Severnoe Izmajlovo  4.190071e+06
#
#        raion_popul  green_zone_part  indust_part  children_preschool  \
# id
# 4104          4001         0.496315     0.007122                 275
# 15625        19940         0.055644     0.243205                1706
# 1287        102618         0.055779     0.136330                5628
# 10576        21819         0.492840     0.075779                1497
# 575          85083         0.051567     0.034331                5586
#
#        preschool_quota  preschool_education_centers_raion  children_school  \
# id
# 4104               NaN                                  0              264
# 15625           2395.0                                  5             1564
# 1287            1944.0                                  4             6141
# 10576              NaN                                  0             1437
# 575             3064.0                                  6             5487
#
#        school_quota  school_education_centers_raion  \
# id
# 4104            NaN                               0
# 15625        7377.0                               5
# 1287         6887.0                               5
# 10576           NaN                               0
# 575          7746.0                               7
#
#        school_education_centers_top_20_raion  hospital_beds_raion  \
# id
# 4104                                       0                  NaN
# 15625                                      0                540.0
# 1287                                       0                262.0
# 10576                                      0                  NaN
# 575                                        0                  NaN
#
#        healthcare_centers_raion  university_top_20_raion  sport_objects_raion  \
# id
# 4104                          0                        0                    0
# 15625                         0                        0                    0
# 1287                          3                        0                    6
# 10576                         0                        0                    3
# 575                           0                        0                    5
#
#        additional_education_raion culture_objects_top_25  \
# id
# 4104                            0                     no
# 15625                           4                     no
# 1287                            4                     no
# 10576                           3                     no
# 575                             3                     no
#
#        culture_objects_top_25_raion  shopping_centers_raion  office_raion  \
# id
# 4104                              0                       1             0
# 15625                             0                       0             0
# 1287                              0                       6            10
# 10576                             0                       2             3
# 575                               0                       4             3
#
#       thermal_power_plant_raion incineration_raion oil_chemistry_raion  \
# id
# 4104                         no                 no                  no
# 15625                        no                yes                  no
# 1287                         no                 no                  no
# 10576                        no                 no                  no
# 575                          no                 no                  no
#
#       radiation_raion railroad_terminal_raion big_market_raion  \
# id
# 4104               no                      no               no
# 15625              no                      no               no
# 1287              yes                      no               no
# 10576              no                      no               no
# 575                no                      no               no
#
#       nuclear_reactor_raion detention_facility_raion  full_all  male_f  \
# id
# 4104                     no                       no     17790    8350
# 15625                    no                       no    247469  112902
# 1287                     no                       no    130396   59093
# 10576                    no                       no      7341    3445
# 575                      no                       no    139322   61324
#
#        female_f  young_all  young_male  young_female  work_all  work_male  \
# id
# 4104       9443        574         297           277      2566       1356
# 15625    134567       3459        1782          1677     13331       6670
# 1287      71303      12524        6442          6082     65782      33606
# 10576      3898       3128        1618          1510     13996       7394
# 575       77998      11746        5968          5778     49742      24624
#
#        work_female  ekder_all  ekder_male  ekder_female  0_6_all  0_6_male  \
# id
# 4104          1211        861         244           617      275       143
# 15625         6661       3150         948          2202     1706       862
# 1287         32176      24312        7633         16679     5628      2817
# 10576         6602       4695        1331          3365     1497       777
# 575          25118      23595        7003         16592     5586      2842
#
#        0_6_female  7_14_all  7_14_male  7_14_female  0_17_all  0_17_male  \
# id
# 4104          133       264        136          128       646        336
# 15625         844      1564        821          743      3831       1973
# 1287         2811      6141       3243         2898     13816       7102
# 10576         721      1437        741          697      3523       1830
# 575          2744      5487       2792         2695     12962       6579
#
#        0_17_female  16_29_all  16_29_male  16_29_female  0_13_all  0_13_male  \
# id
# 4104           311       3796        2035          1762       506        261
# 15625         1858      55710       27242         28468      3112       1600
# 1287          6714      22262       10791         11471     11007       5665
# 10576         1694       1566         840           727      2756       1423
# 575           6383      30010       14284         15726     10406       5301
#
#        0_13_female  raion_build_count_with_material_info  build_count_block  \
# id
# 4104           245                                   NaN                NaN
# 15625         1512                                  43.0                3.0
# 1287          5342                                 316.0              130.0
# 10576         1333                                   1.0                0.0
# 575           5105                                 356.0              191.0
#
#        build_count_wood  build_count_frame  build_count_brick  \
# id
# 4104                NaN                NaN                NaN
# 15625               0.0                0.0               10.0
# 1287                0.0                0.0               28.0
# 10576               1.0                0.0                0.0
# 575                 0.0                0.0               51.0
#
#        build_count_monolith  build_count_panel  build_count_foam  \
# id
# 4104                    NaN                NaN               NaN
# 15625                   2.0               28.0               0.0
# 1287                   18.0              140.0               0.0
# 10576                   0.0                0.0               0.0
# 575                     0.0              114.0               0.0
#
#        build_count_slag  build_count_mix  \
# id
# 4104                NaN              NaN
# 15625               0.0              0.0
# 1287                0.0              0.0
# 10576               0.0              0.0
# 575                 0.0              0.0
#
#        raion_build_count_with_builddate_info  build_count_before_1920  \
# id
# 4104                                     NaN                      NaN
# 15625                                   41.0                      0.0
# 1287                                   316.0                      0.0
# 10576                                    1.0                      0.0
# 575                                    356.0                      0.0
#
#        build_count_1921-1945  build_count_1946-1970  build_count_1971-1995  \
# id
# 4104                     NaN                    NaN                    NaN
# 15625                    1.0                    7.0                   10.0
# 1287                     0.0                  216.0                   52.0
# 10576                    0.0                    1.0                    0.0
# 575                      0.0                  308.0                   22.0
#
#        build_count_after_1995  ID_metro  metro_min_avto  metro_km_avto  \
# id
# 4104                      NaN        21        5.167546       4.557513
# 15625                    23.0       108        4.721045       3.776836
# 1287                     48.0       130        2.420890       1.269687
# 10576                     0.0       206        8.458554       6.732362
# 575                      26.0        20        1.346518       0.655991
#
#        metro_min_walk  metro_km_walk  kindergarten_km  school_km   park_km  \
# id
# 4104        54.901251       4.575104         1.234998   0.760022  7.069501
# 15625       45.322032       3.776836         0.286711   0.214197  4.616176
# 1287        14.736553       1.228046         0.424410   0.311675  1.070181
# 10576       68.402944       5.700245         3.861878   3.532680  6.520123
# 575          7.871895       0.655991         0.329395   0.479919  2.420017
#
#        green_zone_km  industrial_km  water_treatment_km  cemetery_km  \
# id
# 4104        0.505130       1.814376           17.694550     0.541420
# 15625       0.017572       0.394108            0.387777     5.618100
# 1287        0.190437       1.534857            6.728155     3.987095
# 10576       0.183506       0.238926           13.997580     2.486043
# 575         0.307903       0.908837           15.770290     1.490616
#
#        incineration_km  railroad_station_walk_km  railroad_station_walk_min  \
# id
# 4104         21.190720                  3.272308                  39.267700
# 15625         3.194229                  1.923495                  23.081939
# 1287          8.673876                  4.969432                  59.633185
# 10576        18.018980                  7.713678                  92.564133
# 575          12.968040                  5.217632                  62.611579
#
#        ID_railroad_station_walk  railroad_station_avto_km  \
# id
# 4104                      103.0                  5.807462
# 15625                      75.0                  1.923495
# 1287                       42.0                  4.969432
# 10576                      24.0                  8.623783
# 575                        18.0                  5.050715
#
#        railroad_station_avto_min  ID_railroad_station_avto  \
# id
# 4104                    7.405252                        19
# 15625                   3.050727                        75
# 1287                    7.045571                        42
# 10576                  11.935511                        19
# 575                     6.619916                        18
#
#        public_transport_station_km  public_transport_station_min_walk  \
# id
# 4104                      0.532970                           6.395644
# 15625                     0.035986                           0.431838
# 1287                      0.196061                           2.352735
# 10576                     0.133602                           1.603221
# 575                       0.310561                           3.726736
#
#        water_km water_1line   mkad_km     ttk_km  sadovoe_km  bulvar_ring_km  \
# id
# 4104   0.062823         yes  9.635783  19.633077   22.353682       23.521544
# 15625  1.110329          no  5.946908  14.298225   18.418929       19.272537
# 1287   0.460931          no  7.951550   3.900915    6.900182        8.150536
# 10576  1.263289          no  8.184752  18.686365   21.380555       22.548909
# 575    1.718076          no  2.845558   7.585566    9.803117       10.551915
#
#        kremlin_km  big_road1_km  ID_big_road1 big_road1_1line  big_road2_km  \
# id
# 4104    24.392997      2.678893            13              no      3.833386
# 15625   20.549464      1.905125            11              no      2.657336
# 1287     8.858102      2.447700            16              no      3.120004
# 10576   23.373697      0.478623            13              no      6.886762
# 575     12.346542      2.593422            12              no      2.616088
#
#        ID_big_road2  railroad_km railroad_1line  zd_vokzaly_avto_km  \
# id
# 4104             27     1.180730             no           28.534741
# 15625            55     1.214861             no           24.061214
# 1287              2     2.541133             no            9.900398
# 10576            27     3.673876             no           30.927687
# 575              41     1.629999             no           10.599446
#
#        ID_railroad_terminal  bus_terminal_avto_km  ID_bus_terminal  \
# id
# 4104                     50             20.201853                8
# 15625                     5              7.253743               14
# 1287                     32              6.660413                2
# 10576                    50             15.269596                8
# 575                      97              0.958616                7
#
#        oil_chemistry_km  nuclear_reactor_km  radiation_km  \
# id
# 4104          32.284399           19.908381     11.437223
# 15625          8.483391           16.372510      4.317744
# 1287          14.851958            2.954560      1.394806
# 10576         29.546132           18.325112      9.301084
# 575            6.211701           17.075853      1.760136
#
#        power_transmission_line_km  thermal_power_plant_km     ts_km  \
# id
# 4104                     7.794179               12.527192  6.206932
# 15625                    6.380918                9.046319  5.013100
# 1287                     1.513387                3.254240  3.333662
# 10576                    5.601574               12.151073  6.009804
# 575                      2.690655                2.229084  7.308923
#
#        big_market_km  market_shop_km  fitness_km  swim_pool_km  ice_rink_km  \
# id
# 4104       18.381219        9.269074    4.026772      5.356970     5.551130
# 15625      10.264218        5.439734    2.493236      8.106936     8.623789
# 1287        7.170201        2.538304    0.605522      2.269631     7.284917
# 10576      13.448962        9.624964    1.869427      6.507849     6.702009
# 575        16.940834        0.894388    0.600851      0.915176     3.111661
#
#        stadium_km  basketball_km  hospice_morgue_km  detention_facility_km  \
# id
# 4104    16.733799      10.755767           7.538025              27.920092
# 15625   13.591774       5.211201           1.451898              12.239172
# 1287     6.858901       2.129947           0.470561              13.347719
# 10576   11.801542      10.566465           4.952101              30.313039
# 575      4.149512       0.929469           1.088804               8.945486
#
#        public_healthcare_km  university_km  workplaces_km  \
# id
# 4104               4.888188      15.728876      11.586412
# 15625              5.422551       8.837248       5.599071
# 1287               1.941851       1.702188       1.449779
# 10576              6.039067      10.796619       9.907037
# 575                1.089519       1.286711       1.045232
#
#        shopping_centers_km  office_km  additional_education_km  preschool_km  \
# id
# 4104              0.712081   4.535834                 3.647257      0.760022
# 15625             2.215104   4.778766                 0.203466      0.214197
# 1287              1.181820   0.645718                 0.345016      0.311675
# 10576             0.980817   0.980817                 0.594860      3.532680
# 575               0.431747   1.450034                 0.184724      0.479919
#
#        big_church_km  church_synagogue_km  mosque_km  theater_km  museum_km  \
# id
# 4104        3.382706             0.498222  15.124522   16.294785  12.399309
# 15625       3.468289             0.912168  11.891506    9.836242   7.288785
# 1287        1.548151             0.661009   3.077013    2.111952   2.190880
# 10576       4.471586             0.743592  13.188571   11.362528  11.345507
# 575         1.624174             0.894665   9.017966    7.617925   6.333579
#
#        exhibition_km  catering_km       ecology  green_part_500  \
# id
# 4104        7.067967     1.401250       no data            0.00
# 15625       7.402244     1.836073          good           42.63
# 1287        1.811596     0.193291  satisfactory            4.78
# 10576       6.304777     0.537798       no data           21.17
# 575         2.232472     0.293789          good            5.29
#
#        prom_part_500  office_count_500  office_sqm_500  trc_count_500  \
# id
# 4104            0.00                 0               0              0
# 15625           5.76                 0               0              0
# 1287            0.00                 0               0              0
# 10576          14.29                 0               0              0
# 575             0.00                 0               0              2
#
#        trc_sqm_500  cafe_count_500  cafe_sum_500_min_price_avg  \
# id
# 4104             0               0                         NaN
# 15625            0               0                         NaN
# 1287             0               2                      1000.0
# 10576            0               0                         NaN
# 575          37300               9                       700.0
#
#        cafe_sum_500_max_price_avg  cafe_avg_price_500  \
# id
# 4104                          NaN                 NaN
# 15625                         NaN                 NaN
# 1287                      1500.00             1250.00
# 10576                         NaN                 NaN
# 575                       1166.67              933.33
#
#        cafe_count_500_na_price  cafe_count_500_price_500  \
# id
# 4104                         0                         0
# 15625                        0                         0
# 1287                         0                         0
# 10576                        0                         0
# 575                          0                         1
#
#        cafe_count_500_price_1000  cafe_count_500_price_1500  \
# id
# 4104                           0                          0
# 15625                          0                          0
# 1287                           0                          2
# 10576                          0                          0
# 575                            4                          4
#
#        cafe_count_500_price_2500  cafe_count_500_price_4000  \
# id
# 4104                           0                          0
# 15625                          0                          0
# 1287                           0                          0
# 10576                          0                          0
# 575                            0                          0
#
#        cafe_count_500_price_high  big_church_count_500  church_count_500  \
# id
# 4104                           0                     0                 1
# 15625                          0                     0                 0
# 1287                           0                     0                 0
# 10576                          0                     0                 0
# 575                            0                     0                 0
#
#        mosque_count_500  leisure_count_500  sport_count_500  market_count_500  \
# id
# 4104                  0                  0                0                 0
# 15625                 0                  0                0                 0
# 1287                  0                  0                0                 0
# 10576                 0                  0                0                 0
# 575                   0                  0                0                 0
#
#        green_part_1000  prom_part_1000  office_count_1000  office_sqm_1000  \
# id
# 4104             15.75            0.00                  0                0
# 15625            21.22           28.43                  0                0
# 1287              7.81            0.00                  6            98196
# 10576            32.38            4.89                  1           117300
# 575               3.93            0.56                  0                0
#
#        trc_count_1000  trc_sqm_1000  cafe_count_1000  \
# id
# 4104                1         17000                0
# 15625               0             0                0
# 1287                0             0               31
# 10576               1        117300                1
# 575                 2         37300               17
#
#        cafe_sum_1000_min_price_avg  cafe_sum_1000_max_price_avg  \
# id
# 4104                           NaN                          NaN
# 15625                          NaN                          NaN
# 1287                        682.76                      1137.93
# 10576                       500.00                      1000.00
# 575                         658.82                      1088.24
#
#        cafe_avg_price_1000  cafe_count_1000_na_price  \
# id
# 4104                   NaN                         0
# 15625                  NaN                         0
# 1287                910.34                         2
# 10576               750.00                         0
# 575                 873.53                         0
#
#        cafe_count_1000_price_500  cafe_count_1000_price_1000  \
# id
# 4104                           0                           0
# 15625                          0                           0
# 1287                           6                          11
# 10576                          0                           1
# 575                            4                           6
#
#        cafe_count_1000_price_1500  cafe_count_1000_price_2500  \
# id
# 4104                            0                           0
# 15625                           0                           0
# 1287                           11                           1
# 10576                           0                           0
# 575                             7                           0
#
#        cafe_count_1000_price_4000  cafe_count_1000_price_high  \
# id
# 4104                            0                           0
# 15625                           0                           0
# 1287                            0                           0
# 10576                           0                           0
# 575                             0                           0
#
#        big_church_count_1000  church_count_1000  mosque_count_1000  \
# id
# 4104                       0                  1                  0
# 15625                      0                  1                  0
# 1287                       0                  2                  0
# 10576                      0                  2                  0
# 575                        0                  1                  0
#
#        leisure_count_1000  sport_count_1000  market_count_1000  \
# id
# 4104                    0                 0                  0
# 15625                   0                 0                  0
# 1287                    0                 5                  0
# 10576                   0                 0                  0
# 575                     0                 8                  2
#
#        green_part_1500  prom_part_1500  office_count_1500  office_sqm_1500  \
# id
# 4104             30.13            0.00                  0                0
# 15625             9.43           34.86                  0                0
# 1287              9.70            0.00                  8           227196
# 10576            42.82           11.46                  1           117300
# 575               3.85            9.55                  1             6600
#
#        trc_count_1500  trc_sqm_1500  cafe_count_1500  \
# id
# 4104                1         17000                2
# 15625               0             0                0
# 1287                4        153800               61
# 10576               1        117300                1
# 575                 4         46899               23
#
#        cafe_sum_1500_min_price_avg  cafe_sum_1500_max_price_avg  \
# id
# 4104                        650.00                      1000.00
# 15625                          NaN                          NaN
# 1287                        676.27                      1144.07
# 10576                       500.00                      1000.00
# 575                         718.18                      1181.82
#
#        cafe_avg_price_1500  cafe_count_1500_na_price  \
# id
# 4104                825.00                         0
# 15625                  NaN                         0
# 1287                910.17                         2
# 10576               750.00                         0
# 575                 950.00                         1
#
#        cafe_count_1500_price_500  cafe_count_1500_price_1000  \
# id
# 4104                           1                           0
# 15625                          0                           0
# 1287                          13                          24
# 10576                          0                           1
# 575                            6                           7
#
#        cafe_count_1500_price_1500  cafe_count_1500_price_2500  \
# id
# 4104                            1                           0
# 15625                           0                           0
# 1287                           18                           4
# 10576                           0                           0
# 575                             8                           0
#
#        cafe_count_1500_price_4000  cafe_count_1500_price_high  \
# id
# 4104                            0                           0
# 15625                           0                           0
# 1287                            0                           0
# 10576                           0                           0
# 575                             1                           0
#
#        big_church_count_1500  church_count_1500  mosque_count_1500  \
# id
# 4104                       0                  1                  0
# 15625                      0                  2                  0
# 1287                       0                  4                  0
# 10576                      0                  2                  0
# 575                        0                  2                  0
#
#        leisure_count_1500  sport_count_1500  market_count_1500  \
# id
# 4104                    0                 0                  0
# 15625                   0                 0                  0
# 1287                    1                 7                  0
# 10576                   0                 0                  0
# 575                     0                11                  5
#
#        green_part_2000  prom_part_2000  office_count_2000  office_sqm_2000  \
# id
# 4104             35.41            0.19                  0                0
# 15625             5.30           26.61                  0                0
# 1287             10.65            2.05                 19           566705
# 10576            46.43           12.07                  1           117300
# 575               6.04           13.35                  2            11600
#
#        trc_count_2000  trc_sqm_2000  cafe_count_2000  \
# id
# 4104                1         17000                2
# 15625               0             0                2
# 1287                9        332800               91
# 10576               1        117300                1
# 575                 7         84366               35
#
#        cafe_sum_2000_min_price_avg  cafe_sum_2000_max_price_avg  \
# id
# 4104                        650.00                      1000.00
# 15625                       650.00                      1000.00
# 1287                        783.15                      1297.75
# 10576                       500.00                      1000.00
# 575                         711.76                      1191.18
#
#        cafe_avg_price_2000  cafe_count_2000_na_price  \
# id
# 4104                825.00                         0
# 15625               825.00                         0
# 1287               1040.45                         2
# 10576               750.00                         0
# 575                 951.47                         1
#
#        cafe_count_2000_price_500  cafe_count_2000_price_1000  \
# id
# 4104                           1                           0
# 15625                          1                           0
# 1287                          14                          31
# 10576                          0                           1
# 575                            9                          12
#
#        cafe_count_2000_price_1500  cafe_count_2000_price_2500  \
# id
# 4104                            1                           0
# 15625                           1                           0
# 1287                           34                           9
# 10576                           0                           0
# 575                            10                           2
#
#        cafe_count_2000_price_4000  cafe_count_2000_price_high  \
# id
# 4104                            0                           0
# 15625                           0                           0
# 1287                            1                           0
# 10576                           0                           0
# 575                             1                           0
#
#        big_church_count_2000  church_count_2000  mosque_count_2000  \
# id
# 4104                       0                  1                  0
# 15625                      0                  2                  0
# 1287                       1                  6                  0
# 10576                      0                  3                  0
# 575                        2                  5                  0
#
#        leisure_count_2000  sport_count_2000  market_count_2000  \
# id
# 4104                    0                 0                  0
# 15625                   0                 0                  0
# 1287                    2                17                  1
# 10576                   0                 1                  0
# 575                     0                13                  5
#
#        green_part_3000  prom_part_3000  office_count_3000  office_sqm_3000  \
# id
# 4104             36.58            0.56                  0                0
# 15625             2.36           13.06                  0                0
# 1287             10.35           10.13                 33          1038588
# 10576            56.34            6.82                  1           117300
# 575              25.91           16.63                  9           270637
#
#        trc_count_3000  trc_sqm_3000  cafe_count_3000  \
# id
# 4104                1         17000                4
# 15625               2         41100                5
# 1287               17        608240              174
# 10576               1        117300                1
# 575                12        152976               53
#
#        cafe_sum_3000_min_price_avg  cafe_sum_3000_max_price_avg  \
# id
# 4104                        825.00                      1375.00
# 15625                       760.00                      1300.00
# 1287                        768.64                      1284.02
# 10576                       500.00                      1000.00
# 575                         663.27                      1122.45
#
#        cafe_avg_price_3000  cafe_count_3000_na_price  \
# id
# 4104               1100.00                         0
# 15625              1030.00                         0
# 1287               1026.33                         5
# 10576               750.00                         0
# 575                 892.86                         4
#
#        cafe_count_3000_price_500  cafe_count_3000_price_1000  \
# id
# 4104                           1                           1
# 15625                          1                           2
# 1287                          33                          62
# 10576                          0                           1
# 575                           15                          18
#
#        cafe_count_3000_price_1500  cafe_count_3000_price_2500  \
# id
# 4104                            1                           1
# 15625                           1                           1
# 1287                           53                          18
# 10576                           0                           0
# 575                            12                           3
#
#        cafe_count_3000_price_4000  cafe_count_3000_price_high  \
# id
# 4104                            0                           0
# 15625                           0                           0
# 1287                            2                           1
# 10576                           0                           0
# 575                             1                           0
#
#        big_church_count_3000  church_count_3000  mosque_count_3000  \
# id
# 4104                       0                  4                  0
# 15625                      0                  2                  0
# 1287                       4                 14                  0
# 10576                      0                  3                  0
# 575                        4                  8                  0
#
#        leisure_count_3000  sport_count_3000  market_count_3000  \
# id
# 4104                    0                 0                  0
# 15625                   0                 1                  0
# 1287                    4                30                  7
# 10576                   0                 2                  0
# 575                     1                30                  5
#
#        green_part_5000  prom_part_5000  office_count_5000  office_sqm_5000  \
# id
# 4104             39.30            2.50                  1           117300
# 15625             4.46            6.54                  1            26950
# 1287             16.46           12.33                 88          2827142
# 10576            46.77            4.56                  1           117300
# 575              39.90            9.76                 17           339112
#
#        trc_count_5000  trc_sqm_5000  cafe_count_5000  \
# id
# 4104                3        139300               13
# 15625               4         44437               16
# 1287               46       1831364              390
# 10576               3        139300               14
# 575                19        684166               97
#
#        cafe_sum_5000_min_price_avg  cafe_sum_5000_max_price_avg  \
# id
# 4104                        815.38                      1384.62
# 15625                       662.50                      1156.25
# 1287                        750.81                      1254.03
# 10576                       661.54                      1153.85
# 575                         658.24                      1120.88
#
#        cafe_avg_price_5000  cafe_count_5000_na_price  \
# id
# 4104               1100.00                         0
# 15625               909.38                         0
# 1287               1002.42                        18
# 10576               907.69                         1
# 575                 889.56                         6
#
#        cafe_count_5000_price_500  cafe_count_5000_price_1000  \
# id
# 4104                           2                           6
# 15625                          2                           9
# 1287                          96                         123
# 10576                          2                           7
# 575                           28                          35
#
#        cafe_count_5000_price_1500  cafe_count_5000_price_2500  \
# id
# 4104                            3                           1
# 15625                           4                           1
# 1287                          103                          42
# 10576                           3                           1
# 575                            20                           6
#
#        cafe_count_5000_price_4000  cafe_count_5000_price_high  \
# id
# 4104                            1                           0
# 15625                           0                           0
# 1287                            6                           2
# 10576                           0                           0
# 575                             2                           0
#
#        big_church_count_5000  church_count_5000  mosque_count_5000  \
# id
# 4104                       1                  7                  0
# 15625                      2                  3                  0
# 1287                      10                 27                  2
# 10576                      1                  7                  0
# 575                       10                 15                  0
#
#        leisure_count_5000  sport_count_5000  market_count_5000  \
# id
# 4104                    0                 6                  0
# 15625                   0                 6                  1
# 1287                    8                85                 11
# 10576                   0                 8                  0
# 575                     2                50                  5
#
#        timestamp_year  timestamp_month  timestamp_day  timestamp_week  \
# id
# 4104             2012               10              8              41
# 15625            2014                3              3              10
# 1287             2012                2             22               8
# 10576            2013                9             18              38
# 575              2011               12              8              49
#
#        timestamp_dayofweek  timestamp_weekday  timestamp_quarter  \
# id
# 4104                     0                  0                  4
# 15625                    0                  0                  1
# 1287                     2                  2                  1
# 10576                    2                  2                  3
# 575                      3                  3                  4
#
#        timestamp_is_month_start  timestamp_is_month_end  timestamp_is_year_end
# id
# 4104                      False                   False                  False
# 15625                     False                   False                  False
# 1287                      False                   False                  False
# 10576                     False                   False                  False
# 575                       False                   False                  False

# %%
df_train.groupby('timestamp_month')['price_doc'].median().plot()
plt.title('House price variation in the year')
plt.ylabel('mean House price')
# Out:
# Text(0, 0.5, 'mean House price')

# %%
x_train['product_type'].unique()
# Out:
# array(['OwnerOccupier', 'Investment'], dtype=object)

# %%
x_train.select_dtypes(include='O')
# Out:
#         product_type              sub_area culture_objects_top_25  \
# id
# 20087  OwnerOccupier           Presnenskoe                    yes
# 616       Investment          Dorogomilovo                     no
# 19231     Investment               Donskoe                    yes
# 27987     Investment        Fili Davydkovo                     no
# 13321     Investment           Danilovskoe                     no
# ...              ...                   ...                    ...
# 1768      Investment         Levoberezhnoe                     no
# 12153     Investment        Filevskij Park                     no
# 20419  OwnerOccupier  Poselenie Vnukovskoe                     no
# 17097     Investment             Rostokino                     no
# 11725     Investment             Lianozovo                     no
#
#       thermal_power_plant_raion incineration_raion oil_chemistry_raion  \
# id
# 20087                        no                 no                  no
# 616                         yes                 no                  no
# 19231                        no                 no                  no
# 27987                        no                 no                  no
# 13321                       yes                 no                  no
# ...                         ...                ...                 ...
# 1768                         no                 no                  no
# 12153                        no                 no                  no
# 20419                        no                 no                  no
# 17097                        no                 no                  no
# 11725                        no                 no                  no
#
#       radiation_raion railroad_terminal_raion big_market_raion  \
# id
# 20087             yes                      no               no
# 616               yes                     yes               no
# 19231             yes                      no               no
# 27987             yes                      no               no
# 13321              no                      no               no
# ...               ...                     ...              ...
# 1768              yes                      no               no
# 12153             yes                      no               no
# 20419              no                      no               no
# 17097              no                      no               no
# 11725             yes                      no               no
#
#       nuclear_reactor_raion detention_facility_raion water_1line  \
# id
# 20087                    no                       no          no
# 616                      no                       no          no
# 19231                    no                       no          no
# 27987                    no                       no          no
# 13321                    no                       no         yes
# ...                     ...                      ...         ...
# 1768                     no                       no          no
# 12153                    no                       no          no
# 20419                    no                       no          no
# 17097                    no                       no          no
# 11725                    no                       no          no
#
#       big_road1_1line railroad_1line       ecology
# id
# 20087              no             no          poor
# 616                no             no          poor
# 19231              no            yes          poor
# 27987              no             no  satisfactory
# 13321              no             no     excellent
# ...               ...            ...           ...
# 1768               no             no  satisfactory
# 12153              no             no  satisfactory
# 20419              no             no       no data
# 17097              no             no          poor
# 11725              no             no          poor
#
# [21330 rows x 15 columns]

# %%
cat_cols=x_train.select_dtypes(include=['O','bool']).columns; cat_cols
# Out:
# Index(['product_type', 'sub_area', 'culture_objects_top_25',
#        'thermal_power_plant_raion', 'incineration_raion',
#        'oil_chemistry_raion', 'radiation_raion', 'railroad_terminal_raion',
#        'big_market_raion', 'nuclear_reactor_raion', 'detention_facility_raion',
#        'water_1line', 'big_road1_1line', 'railroad_1line', 'ecology',
#        'timestamp_is_month_start', 'timestamp_is_month_end',
#        'timestamp_is_year_end'],
#       dtype='object')

# %%
x_train.shape
# Out:
# (21330, 299)

# %%
len(cat_cols)
# Out:
# 18

# %%
x_train.select_dtypes(include=['int','float'])
# Out:
#        life_sq  floor  max_floor  material  build_year  num_room  kitch_sq  \
# id
# 20087    112.0    7.0        9.0       4.0      2017.0       3.0      12.0
# 616       16.0    2.0        NaN       NaN         NaN       NaN       NaN
# 19231     44.0    5.0       12.0       5.0      1970.0       3.0       9.0
# 27987     26.0    1.0        5.0       2.0      1967.0       2.0       5.0
# 13321     23.0    9.0        9.0       1.0      1963.0       2.0       7.0
# ...        ...    ...        ...       ...         ...       ...       ...
# 1768      20.0    NaN        NaN       NaN         NaN       NaN       NaN
# 12153     38.0    8.0       17.0       1.0      1989.0       1.0       8.0
# 20419     62.0    9.0       17.0       1.0      2014.0       2.0       1.0
# 17097     20.0    3.0        5.0       5.0      1966.0       1.0       5.0
# 11725     18.0   11.0       17.0       6.0      2005.0       1.0       9.0
#
#        state        area_m  green_zone_part  ...  green_part_3000  \
# id                                           ...
# 20087    1.0  1.163805e+07         0.068202  ...             4.32
# 616      NaN  7.798452e+06         0.199431  ...             7.35
# 19231    3.0  5.686537e+06         0.073521  ...            10.07
# 27987    3.0  6.982964e+06         0.348986  ...            26.65
# 13321    3.0  1.249544e+07         0.027651  ...             3.30
# ...      ...           ...              ...  ...              ...
# 1768     NaN  6.424174e+06         0.216361  ...            15.76
# 12153    3.0  9.629358e+06         0.343754  ...            22.78
# 20419    1.0  2.553630e+07         0.496315  ...            44.37
# 17097    3.0  3.497819e+06         0.146941  ...            31.26
# 11725    NaN  5.646405e+06         0.258663  ...            24.81
#
#        prom_part_3000  cafe_sum_3000_min_price_avg  \
# id
# 20087           18.10                       986.99
# 616              4.09                       974.04
# 19231           17.99                       795.78
# 27987           12.73                      1075.61
# 13321           16.02                       800.95
# ...               ...                          ...
# 1768             9.60                       576.06
# 12153           15.05                      1030.00
# 20419            1.97                       680.00
# 17097           13.28                       759.77
# 11725           16.71                       780.65
#
#        cafe_sum_3000_max_price_avg  cafe_avg_price_3000  green_part_5000  \
# id
# 20087                      1616.76              1301.87            10.43
# 616                        1596.40              1285.22            11.20
# 19231                      1325.30              1060.54            11.63
# 27987                      1780.49              1428.05            19.55
# 13321                      1321.85              1061.40             6.26
# ...                            ...                  ...              ...
# 1768                        985.92               780.99            16.99
# 12153                      1714.29              1372.14            19.43
# 20419                      1200.00               940.00            35.66
# 17097                      1287.36              1023.56            29.49
# 11725                      1274.19              1027.42            17.67
#
#        prom_part_5000  cafe_sum_5000_min_price_avg  \
# id
# 20087           12.31                       930.94
# 616              9.66                       905.79
# 19231           12.34                       786.93
# 27987           12.57                       943.71
# 13321           21.43                       832.36
# ...               ...                          ...
# 1768            15.14                       728.19
# 12153           10.03                      1027.51
# 20419            6.07                       747.37
# 17097           13.52                       694.74
# 11725           13.21                       750.00
#
#        cafe_sum_5000_max_price_avg  cafe_avg_price_5000
# id
# 20087                      1531.66              1231.30
# 616                        1490.51              1198.15
# 19231                      1308.15              1047.54
# 27987                      1566.23              1254.97
# 13321                      1374.73              1103.54
# ...                            ...                  ...
# 1768                       1221.48               974.83
# 12153                      1687.68              1357.59
# 20419                      1263.16              1005.26
# 17097                      1173.68               934.21
# 11725                      1250.00              1000.00
#
# [21330 rows x 119 columns]

# %%
num_cols=list(x_train.select_dtypes(include=['int', 'float']).columns)
median_imputer = mdi.MeanMedianImputer(imputation_method='median',variables=num_cols)
median_imputer.fit(x_train)
# Out:
# MeanMedianImputer(imputation_method='median',
#                   variables=['life_sq', 'floor', 'max_floor', 'material',
#                              'build_year', 'num_room', 'kitch_sq', 'state',
#                              'area_m', 'green_zone_part', 'indust_part',
#                              'preschool_quota', 'school_quota',
#                              'hospital_beds_raion',
#                              'raion_build_count_with_material_info',
#                              'build_count_block', 'build_count_wood',
#                              'build_count_frame', 'build_count_brick',
#                              'build_count_monolith', 'build_count_panel',
#                              'build_count_foam', 'build_count_slag',
#                              'build_count_mix',
#                              'raion_build_count_with_builddate_info',
#                              'build_count_before_1920', 'build_count_1921-1945',
#                              'build_count_1946-1970', 'build_count_1971-1995',
#                              'build_count_after_1995', ...])

# %%
len(num_cols)
# Out:
# 119

# %%
x_train.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('float64'), dtype('O'), dtype('bool')],
#       dtype=object)

# %%
cats=list(set(x_train.columns)-set(num_cols)); len(cats)
# Out:
# 180

# %%
x_train[cats].head()
# Out:
#        16_29_male  trc_count_1500  0_13_all  16_29_female  \
# id
# 20087        4834               2     13121          5350
# 616          2311               7      4999          2319
# 19231        8474               2      6237          9390
# 27987       10333               5     13592          8765
# 13321       11769               5     10869         12527
#
#        cafe_count_2000_price_2500  market_count_1000  \
# id
# 20087                          40                  0
# 616                            76                  1
# 19231                           9                  0
# 27987                           2                  0
# 13321                          29                  1
#
#        ID_railroad_station_avto radiation_raion  young_male  \
# id
# 20087                        71             yes        7789
# 616                          50             yes        2917
# 19231                        42             yes        3519
# 27987                        22             yes        7766
# 13321                        44              no        6137
#
#        big_church_count_3000  ...  timestamp_month  church_count_5000  \
# id                            ...
# 20087                     13  ...                6                120
# 616                       35  ...               12                177
# 19231                     15  ...                6                 60
# 27987                      4  ...                2                 23
# 13321                     45  ...               12                178
#
#        sport_count_500  female_f  trc_sqm_5000  cafe_count_1500  \
# id
# 20087                2     32388       3364547              115
# 616                  4     11324       3395349              267
# 19231                1     51873       2654046               19
# 27987                0     41757       1531705               11
# 13321                0     54484       3888804               95
#
#        mosque_count_5000  market_count_3000  cafe_count_1000_na_price  \
# id
# 20087                  0                  3                         9
# 616                    2                  3                        11
# 19231                  0                  2                         0
# 27987                  1                  1                         1
# 13321                  1                  7                         0
#
#        culture_objects_top_25
# id
# 20087                     yes
# 616                        no
# 19231                     yes
# 27987                      no
# 13321                      no
#
# [5 rows x 180 columns]

# %%
df_train[categorical].nunique().plot.bar(figsize=(10,6))
plt.title('CARDINALITY: Number of categories in categorical variables')
plt.xlabel('Categorical variables')
plt.ylabel('Number of different categories')
# Out:
# Text(0, 0.5, 'Number of different categories')

# %%
x_train[discrete] = x_train[discrete].astype('O')
x_val[discrete] = x_val[discrete].astype('O')

# %%
numerical = [var for var in df_train.columns if df_train[var].dtype!='O']
numerical = [var for var in numerical if var not in discrete and var not in ['price_doc']]

# %%
pipe = Pipeline([

    # missing data imputation - section 4
    ('missing_ind', mdi.AddNaNBinaryImputer(
        variables=discrete)),
    ('imputer_num', mdi.MeanMedianImputer(imputation_method='mean',
                                          variables=continuous)),
    ('imputer_cat', mdi.CategoricalVariableImputer(variables=categorical+discrete)),

    # categorical encoding - section 6
    ('rare_label_enc', ce.RareLabelCategoricalEncoder(
        tol=0.05, n_categories=6, variables=categorical+discrete)),
    ('categorical_enc', ce.OrdinalCategoricalEncoder(
        encoding_method='ordered', variables=categorical+discrete)),

    # discretisation + encoding
    ('discretisation', dsc.EqualFrequencyDiscretiser(
        q=5, return_object=True, variables=numerical)),
    ('encoding', ce.OrdinalCategoricalEncoder(
        encoding_method='ordered', variables=numerical)),

    # feature Scaling
    ('scaler', StandardScaler()),
    
    # regression
    ('lasso', Lasso(random_state=0))
])

# %%
pipe.fit(x_train, y_train)
# Out:
# D:\narain\anaconda3\envs\ml\lib\site-packages\sklearn\utils\validation.py:933: FutureWarning: Passing attributes to check_is_fitted is deprecated and will be removed in 0.23. The attributes argument is ignored.
#   "argument is ignored.", FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-150-766b9f445e70> in <module>
# ----> 1 pipe.fit(x_train, y_train)
#
# D:\narain\anaconda3\envs\ml\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     346             This estimator
#     347         """
# --> 348         Xt, fit_params = self._fit(X, y, **fit_params)
#     349         with _print_elapsed_time('Pipeline',
#     350                                  self._log_message(len(self.steps) - 1)):
#
# D:\narain\anaconda3\envs\ml\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params)
#     311                 message_clsname='Pipeline',
#     312                 message=self._log_message(step_idx),
# --> 313                 **fit_params_steps[name])
#     314             # Replace the transformer of the step with the fitted
#     315             # transformer. This is necessary when loading the transformer
#
# D:\narain\anaconda3\envs\ml\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# D:\narain\anaconda3\envs\ml\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     724     with _print_elapsed_time(message_clsname, message):
#     725         if hasattr(transformer, 'fit_transform'):
# --> 726             res = transformer.fit_transform(X, y, **fit_params)
#     727         else:
#     728             res = transformer.fit(X, y, **fit_params).transform(X)
#
# D:\narain\anaconda3\envs\ml\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
# --> 574             return self.fit(X, y, **fit_params).transform(X)
#     575
#     576
#
# D:\narain\anaconda3\envs\ml\lib\site-packages\feature_engine\categorical_encoders.py in fit(self, X, y)
#     597         """
#     598         # brings the variables from the BaseEncoder
# --> 599         super().fit(X, y)
#     600
#     601         self.encoder_dict_ = {}
#
# D:\narain\anaconda3\envs\ml\lib\site-packages\feature_engine\base_transformers.py in fit(self, X, y)
#     171 #            for var in self.variables:
#     172 #                if X[var].dtypes != 'O':
# --> 173                 raise TypeError("variable {} is not of type object, check that all indicated variables are of type object before calling the transformer")
#     174             self.variables = self.variables
#     175
#
# TypeError: variable {} is not of type object, check that all indicated variables are of type object before calling the transformer

# %%
x_train_preds=pipe.fit(x_train)
x_val_preds=pipe.fit(x_val)
