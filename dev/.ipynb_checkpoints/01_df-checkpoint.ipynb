# %%
# %matplotlib inline

# %%
from pathlib import Path
import pandas as pd
import numpy as np
from sklearn.linear_model import Lasso
# from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score
# from sklearn.preprocessing import StandardScaler
# from feature_engine import missing_data_imputers as mdi
# from feature_engine import discretisers as dsc
# from feature_engine import categorical_encoders as ce
import matplotlib.pyplot as plt

pd.pandas.set_option('display.max_columns', None)
Path.ls=lambda x: list(x.iterdir())

# %%
path_data=Path(r'D:\datasets\new_datasets')
list(path_data.iterdir())
# Out:
# [WindowsPath('D:/datasets/new_datasets/caterpillar-tube-pricing'),
#  WindowsPath('D:/datasets/new_datasets/costa-rican-household-poverty-prediction'),
#  WindowsPath('D:/datasets/new_datasets/flavours-of-physics-kernels-only'),
#  WindowsPath('D:/datasets/new_datasets/higgs-boson'),
#  WindowsPath('D:/datasets/new_datasets/leaf-classification'),
#  WindowsPath('D:/datasets/new_datasets/mercedes-benz-greener-manufacturing'),
#  WindowsPath('D:/datasets/new_datasets/msk-redefining-cancer-treatment'),
#  WindowsPath('D:/datasets/new_datasets/MusicHackathon'),
#  WindowsPath('D:/datasets/new_datasets/nomad2018-predict-transparent-conductors'),
#  WindowsPath('D:/datasets/new_datasets/porto-seguro-safe-driver-prediction'),
#  WindowsPath('D:/datasets/new_datasets/predict-west-nile-virus'),
#  WindowsPath('D:/datasets/new_datasets/predict-who-is-more-influential-in-a-social-network'),
#  WindowsPath('D:/datasets/new_datasets/random-acts-of-pizza'),
#  WindowsPath('D:/datasets/new_datasets/recruit-restaurant-visitor-forecasting'),
#  WindowsPath('D:/datasets/new_datasets/sberbank-russian-housing-market'),
#  WindowsPath('D:/datasets/new_datasets/spooky-author-identification'),
#  WindowsPath('D:/datasets/new_datasets/whats-cooking')]

# %%
path_house=path_data/'sberbank-russian-housing-market'
list(path_house.iterdir())
# Out:
# [WindowsPath('D:/datasets/new_datasets/sberbank-russian-housing-market/data_dictionary.txt'),
#  WindowsPath('D:/datasets/new_datasets/sberbank-russian-housing-market/macro.csv.zip'),
#  WindowsPath('D:/datasets/new_datasets/sberbank-russian-housing-market/New folder'),
#  WindowsPath('D:/datasets/new_datasets/sberbank-russian-housing-market/sample_submission.csv.zip'),
#  WindowsPath('D:/datasets/new_datasets/sberbank-russian-housing-market/test.csv'),
#  WindowsPath('D:/datasets/new_datasets/sberbank-russian-housing-market/train.csv'),
#  WindowsPath('D:/datasets/new_datasets/sberbank-russian-housing-market/__MACOSX')]

# %%
path_house_train=path_house/'train.csv'
path_house_test=path_house/'test.csv'

# %%
df_train=pd.read_csv(path_house_train, index_col='id', parse_dates=['timestamp'], infer_datetime_format=True)
df_train.head()
# Out:
#     timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# id
# 1  2011-08-20       43     27.0    4.0        NaN       NaN         NaN
# 2  2011-08-23       34     19.0    3.0        NaN       NaN         NaN
# 3  2011-08-27       43     29.0    2.0        NaN       NaN         NaN
# 4  2011-09-01       89     50.0    9.0        NaN       NaN         NaN
# 5  2011-09-05       77     77.0    4.0        NaN       NaN         NaN
#
#     num_room  kitch_sq  state product_type           sub_area        area_m  \
# id
# 1        NaN       NaN    NaN   Investment           Bibirevo  6.407578e+06
# 2        NaN       NaN    NaN   Investment  Nagatinskij Zaton  9.589337e+06
# 3        NaN       NaN    NaN   Investment     Tekstil'shhiki  4.808270e+06
# 4        NaN       NaN    NaN   Investment             Mitino  1.258354e+07
# 5        NaN       NaN    NaN   Investment          Basmannoe  8.398461e+06
#
#     raion_popul  green_zone_part  indust_part  children_preschool  \
# id
# 1        155572         0.189727     0.000070                9576
# 2        115352         0.372602     0.049637                6880
# 3        101708         0.112560     0.118537                5879
# 4        178473         0.194703     0.069753               13087
# 5        108171         0.015234     0.037316                5706
#
#     preschool_quota  preschool_education_centers_raion  children_school  \
# id
# 1            5001.0                                  5            10309
# 2            3119.0                                  5             7759
# 3            1463.0                                  4             6207
# 4            6839.0                                  9            13670
# 5            3240.0                                  7             6748
#
#     school_quota  school_education_centers_raion  \
# id
# 1        11065.0                               5
# 2         6237.0                               8
# 3         5580.0                               7
# 4        17063.0                              10
# 5         7770.0                               9
#
#     school_education_centers_top_20_raion  hospital_beds_raion  \
# id
# 1                                       0                240.0
# 2                                       0                229.0
# 3                                       0               1183.0
# 4                                       0                  NaN
# 5                                       0                562.0
#
#     healthcare_centers_raion  university_top_20_raion  sport_objects_raion  \
# id
# 1                          1                        0                    7
# 2                          1                        0                    6
# 3                          1                        0                    5
# 4                          1                        0                   17
# 5                          4                        2                   25
#
#     additional_education_raion culture_objects_top_25  \
# id
# 1                            3                     no
# 2                            1                    yes
# 3                            1                     no
# 4                            6                     no
# 5                            2                     no
#
#     culture_objects_top_25_raion  shopping_centers_raion  office_raion  \
# id
# 1                              0                      16             1
# 2                              1                       3             0
# 3                              0                       0             1
# 4                              0                      11             4
# 5                              0                      10            93
#
#    thermal_power_plant_raion incineration_raion oil_chemistry_raion  \
# id
# 1                         no                 no                  no
# 2                         no                 no                  no
# 3                         no                 no                  no
# 4                         no                 no                  no
# 5                         no                 no                  no
#
#    radiation_raion railroad_terminal_raion big_market_raion  \
# id
# 1               no                      no               no
# 2               no                      no               no
# 3              yes                      no               no
# 4               no                      no               no
# 5              yes                     yes               no
#
#    nuclear_reactor_raion detention_facility_raion  full_all  male_f  female_f  \
# id
# 1                     no                       no     86206   40477     45729
# 2                     no                       no     76284   34200     42084
# 3                     no                       no    101982   46076     55906
# 4                     no                       no     21155    9828     11327
# 5                     no                       no     28179   13522     14657
#
#     young_all  young_male  young_female  work_all  work_male  work_female  \
# id
# 1       21154       11007         10147     98207      52277        45930
# 2       15727        7925          7802     70194      35622        34572
# 3       13028        6835          6193     63388      31813        31575
# 4       28563       14680         13883    120381      60040        60341
# 5       13368        7159          6209     68043      34236        33807
#
#     ekder_all  ekder_male  ekder_female  0_6_all  0_6_male  0_6_female  \
# id
# 1       36211       10580         25631     9576      4899        4677
# 2       29431        9266         20165     6880      3466        3414
# 3       25292        7609         17683     5879      3095        2784
# 4       29529        9083         20446    13087      6645        6442
# 5       26760        8563         18197     5706      2982        2724
#
#     7_14_all  7_14_male  7_14_female  0_17_all  0_17_male  0_17_female  \
# id
# 1      10309       5463         4846     23603      12286        11317
# 2       7759       3909         3850     17700       8998         8702
# 3       6207       3269         2938     14884       7821         7063
# 4      13670       7126         6544     32063      16513        15550
# 5       6748       3664         3084     15237       8113         7124
#
#     16_29_all  16_29_male  16_29_female  0_13_all  0_13_male  0_13_female  \
# id
# 1       17508        9425          8083     18654       9709         8945
# 2       15164        7571          7593     13729       6929         6800
# 3       19401        9045         10356     11252       5916         5336
# 4        3292        1450          1842     24934      12782        12152
# 5        5164        2583          2581     11631       6223         5408
#
#     raion_build_count_with_material_info  build_count_block  build_count_wood  \
# id
# 1                                  211.0               25.0               0.0
# 2                                  245.0               83.0               1.0
# 3                                  330.0               59.0               0.0
# 4                                  458.0                9.0              51.0
# 5                                  746.0               48.0               0.0
#
#     build_count_frame  build_count_brick  build_count_monolith  \
# id
# 1                 0.0                0.0                   2.0
# 2                 0.0               67.0                   4.0
# 3                 0.0              206.0                   4.0
# 4                12.0              124.0                  50.0
# 5                 0.0              643.0                  16.0
#
#     build_count_panel  build_count_foam  build_count_slag  build_count_mix  \
# id
# 1               184.0               0.0               0.0              0.0
# 2                90.0               0.0               0.0              0.0
# 3                60.0               0.0               1.0              0.0
# 4               201.0               0.0               9.0              2.0
# 5                35.0               0.0               3.0              1.0
#
#     raion_build_count_with_builddate_info  build_count_before_1920  \
# id
# 1                                   211.0                      0.0
# 2                                   244.0                      1.0
# 3                                   330.0                      1.0
# 4                                   459.0                     13.0
# 5                                   746.0                    371.0
#
#     build_count_1921-1945  build_count_1946-1970  build_count_1971-1995  \
# id
# 1                     0.0                    0.0                  206.0
# 2                     1.0                  143.0                   84.0
# 3                     0.0                  246.0                   63.0
# 4                    24.0                   40.0                  130.0
# 5                   114.0                  146.0                   62.0
#
#     build_count_after_1995  ID_metro  metro_min_avto  metro_km_avto  \
# id
# 1                      5.0         1        2.590241       1.131260
# 2                     15.0         2        0.936700       0.647337
# 3                     20.0         3        2.120999       1.637996
# 4                    252.0         4        1.489049       0.984537
# 5                     53.0         5        1.257186       0.876620
#
#     metro_min_walk  metro_km_walk  kindergarten_km  school_km   park_km  \
ospice_morgue_km  detention_facility_km  public_healthcare_km  \
# id
# 1            2.392353               4.248036              0.974743
# 2            2.543747              12.649879              1.477723
# 3            0.621357               7.682303              0.097144
# 4            3.549558               8.789894              2.163735
# 5            1.864637               3.779781              1.121703
#
#     university_km  workplaces_km  shopping_centers_km  office_km  \
# id
# 1        6.715026       0.884350             0.648488   0.637189
# 2        1.852560       0.686252             0.519311   0.688796
# 3        0.841254       1.510089             1.486533   1.543049
# 4       10.903161       0.622272             0.599914   0.934273
# 5        0.991683       0.892668             0.429052   0.077901
#
#     additional_education_km  preschool_km  big_church_km  church_synagogue_km  \
# id
# 1                  0.947962      0.177975       0.625783             0.628187
# 2                  1.072315      0.273345       0.967821             0.471447
# 3                  0.391957      0.158072       3.178751             0.755946
# 4                  0.892674      0.236455       1.031777             1.561505
# 5                  0.810801      0.376838       0.378756             0.121681
#
#     mosque_km  theater_km  museum_km  exhibition_km  catering_km    ecology  \
# id
# 1    3.932040   14.053047   7.389498       7.023705     0.516838       good
# 2    4.841544    6.829889   0.709260       2.358840     0.230287  excellent
# 3    7.922152    4.273200   3.156423       4.958214     0.190462       poor
# 4   15.300449   16.990677  16.041521       5.029696     0.465820       good
# 5    2.584370    1.112486   1.800125       1.339652     0.026102  excellent
#
#     green_part_500  prom_part_500  office_count_500  office_sqm_500  \
# id
# 1             0.00           0.00                 0               0
# 2            25.14           0.00                 0               0
# 3             1.67           0.00                 0               0
# 4            17.36           0.57                 0               0
# 5             3.56           4.44                15          293699
#
#     trc_count_500  trc_sqm_500  cafe_count_500  cafe_sum_500_min_price_avg  \
# id
# 1               0            0               0                         NaN
# 2               0            0               5                      860.00
# 3               0            0               3                      666.67
# 4               0            0               2                     1000.00
# 5               1        45000              48                      702.22
#
#     cafe_sum_500_max_price_avg  cafe_avg_price_500  cafe_count_500_na_price  \
# id
# 1                          NaN                 NaN                        0
# 2                      1500.00             1180.00                        0
# 3                      1166.67              916.67                        0
# 4                      1500.00             1250.00                        0
# 5                      1166.67              934.44                        3
#
#     cafe_count_500_price_500  cafe_count_500_price_1000  \
# id
# 1                          0                          0
# 2                          1                          3
# 3                          0                          2
# 4                          0                          0
# 5                         17                         10
#
#     cafe_count_500_price_1500  cafe_count_500_price_2500  \
# id
# 1                           0                          0
# 2                           0                          0
# 3                           1                          0
# 4                           2                          0
# 5                          11                          7
#
#     cafe_count_500_price_4000  cafe_count_500_price_high  \
# id
# 1                           0                          0
# 2                           1                          0
# 3                           0                          0
# 4                           0                          0
# 5                           0                          0
#
#     big_church_count_500  church_count_500  mosque_count_500  \
# id
# 1                      0                 0                 0
# 2                      0                 1                 0
# 3                      0                 0                 0
# 4                      0                 0                 0
# 5                      1                 4                 0
#
#     leisure_count_500  sport_count_500  market_count_500  green_part_1000  \
# id
# 1                   0                1                 0             7.36
# 2                   0                0                 0            26.66
# 3                   0                0                 0             4.99
# 4                   0                0                 0            19.25
# 5                   2                3                 0             3.34
#
#     prom_part_1000  office_count_1000  office_sqm_1000  trc_count_1000  \
# id
# 1             0.00                  1            30500               3
# 2             0.07                  2            86600               5
# 3             0.29                  0                0               0
# 4            10.35                  1            11000               6
# 5             8.29                 46           420952               3
#
#     trc_sqm_1000  cafe_count_1000  cafe_sum_1000_min_price_avg  \
# id
# 1          55600               19                       527.78
# 2          94065               13                       615.38
# 3              0                9                       642.86
# 4          80780               12                       658.33
# 5         158200              153                       763.45
#
#     cafe_sum_1000_max_price_avg  cafe_avg_price_1000  \
# id
# 1                        888.89               708.33
# 2                       1076.92               846.15
# 3                       1142.86               892.86
# 4                       1083.33               870.83
# 5                       1272.41              1017.93
#
#     cafe_count_1000_na_price  cafe_count_1000_price_500  \
# id
# 1                          1                         10
# 2                          0                          5
# 3                          2                          0
# 4                          0                          3
# 5                          8                         39
#
#     cafe_count_1000_price_1000  cafe_count_1000_price_1500  \
# id
# 1                            4                           3
# 2                            6                           1
# 3                            5                           2
# 4                            4                           5
# 5                           45                          39
#
#     cafe_count_1000_price_2500  cafe_count_1000_price_4000  \
# id
# 1                            1                           0
# 2                            0                           1
# 3                            0                           0
# 4                            0                           0
# 5                           19                           2
#
#     cafe_count_1000_price_high  big_church_count_1000  church_count_1000  \
# id
# 1                            0                      1                  2
# 2                            0                      1                  2
# 3                            0                      0                  1
# 4                            0                      0                  0
# 5                            1                      7                 12
#
#     mosque_count_1000  leisure_count_1000  sport_count_1000  \
# id
# 1                   0                   0                 6
# 2                   0                   4                 2
# 3                   0                   0                 5
# 4                   0                   0                 3
# 5                   0                   6                 7
#
#     market_count_1000  green_part_1500  prom_part_1500  office_count_1500  \
# id
# 1                   1            14.27            6.92                  3
# 2                   0            21.53            7.71                  3
# 3                   3             9.92            6.73                  0
# 4                   1            28.38            6.57                  2
# 5                   0             4.12            4.83                 93
#
#     office_sqm_1500  trc_count_1500  trc_sqm_1500  cafe_count_1500  \
# id
# 1             39554               9        171420               34
# 2            102910               7        127065               17
# 3                 0               1          2600               14
# 4             11000               7         89492               23
# 5           1195735               9        445900              272
#
#     cafe_sum_1500_min_price_avg  cafe_sum_1500_max_price_avg  \
# id
# 1                        566.67                       969.70
# 2                        694.12                      1205.88
# 3                        516.67                       916.67
# 4                        673.91                      1130.43
# 5                        766.80                      1272.73
#
#     cafe_avg_price_1500  cafe_count_1500_na_price  cafe_count_1500_price_500  \
# id
# 1                768.18                         1                         14
# 2                950.00                         0                          6
# 3                716.67                         2                          4
# 4                902.17                         0                          5
# 5               1019.76                        19                         70
#
#     cafe_count_1500_price_1000  cafe_count_1500_price_1500  \
# id
# 1                           11                           6
# 2                            7                           1
# 3                            6                           2
# 4                            9                           8
# 5                           74                          72
#
#     cafe_count_1500_price_2500  cafe_count_1500_price_4000  \
# id
# 1                            2                           0
# 2                            2                           1
# 3                            0                           0
# 4                            1                           0
# 5                           30                           6
#
#     cafe_count_1500_price_high  big_church_count_1500  church_count_1500  \
# id
# 1                            0                      1                  2
# 2                            0                      1                  5
# 3                            0                      0                  4
# 4                            0                      1                  0
# 5                            1                     18                 30
#
#     mosque_count_1500  leisure_count_1500  sport_count_1500  \
# id
# 1                   0                   0                 7
# 2                   0                   4                 9
# 3                   0                   0                 6
# 4                   0                   0                 9
# 5                   0                  10                14
#
#     market_count_1500  green_part_2000  prom_part_2000  office_count_2000  \
# id
# 1                   1            11.77           15.97                  9
# 2                   0            22.37           19.25                  4
# 3                   5            12.99           12.75                  4
# 4                   2            32.29            5.73                  2
# 5                   2             4.53            5.02                149
#
#     office_sqm_2000  trc_count_2000  trc_sqm_2000  cafe_count_2000  \
# id
# 1            188854              19       1244891               36
# 2            165510               8        179065               21
# 3            100200               7         52550               24
# 4             11000               7         89492               25
# 5           1625130              17        564843              483
#
#     cafe_sum_2000_min_price_avg  cafe_sum_2000_max_price_avg  \
# id
# 1                        614.29                      1042.86
# 2                        695.24                      1190.48
# 3                        563.64                       977.27
# 4                        660.00                      1120.00
# 5                        765.93                      1269.23
#
#     cafe_avg_price_2000  cafe_count_2000_na_price  cafe_count_2000_price_500  \
# id
# 1                828.57                         1                         15
# 2                942.86                         0                          7
# 3                770.45                         2                          8
# 4                890.00                         0                          5
# 5               1017.58                        28                        130
#
#     cafe_count_2000_price_1000  cafe_count_2000_price_1500  \
# id
# 1                           11                           6
# 2                            8                           3
# 3                            9                           4
# 4                           11                           8
# 5                          129                         131
#
#     cafe_count_2000_price_2500  cafe_count_2000_price_4000  \
# id
# 1                            2                           1
# 2                            2                           1
# 3                            1                           0
# 4                            1                           0
# 5                           50                          14
#
#     cafe_count_2000_price_high  big_church_count_2000  church_count_2000  \
# id
# 1                            0                      1                  2
# 2                            0                      1                  5
# 3                            0                      0                  4
# 4                            0                      1                  1
# 5                            1                     35                 61
#
#     mosque_count_2000  leisure_count_2000  sport_count_2000  \
# id
# 1                   0                   0                10
# 2                   0                   4                11
# 3                   0                   0                 8
# 4                   0                   0                13
# 5                   0                  17                21
#
#     market_count_2000  green_part_3000  prom_part_3000  office_count_3000  \
# id
# 1                   1            11.98           13.55                 12
# 2                   0            18.07           27.32                 12
# 3                   5            12.14           26.46                  8
# 4                   2            20.79            3.57                  4
# 5                   3             5.06            8.62                305
#
#     office_sqm_3000  trc_count_3000  trc_sqm_3000  cafe_count_3000  \
# id
# 1            251554              23       1419204               68
# 2            821986              14        491565               30
# 3            110856               7         52550               41
# 4            167000              12        205756               32
# 5           3420907              60       2296870             1068
#
#     cafe_sum_3000_min_price_avg  cafe_sum_3000_max_price_avg  \
# id
# 1                        639.68                      1079.37
# 2                        631.03                      1086.21
# 3                        697.44                      1192.31
# 4                        718.75                      1218.75
# 5                        853.03                      1410.45
#
#     cafe_avg_price_3000  cafe_count_3000_na_price  cafe_count_3000_price_500  \
# id
# 1                859.52                         5                         21
# 2                858.62                         1                         11
# 3                944.87                         2                          9
# 4                968.75                         0                          5
# 5               1131.74                        63                        266
#
#     cafe_count_3000_price_1000  cafe_count_3000_price_1500  \
# id
# 1                           22                          16
# 2                           11                           4
# 3                           17                           9
# 4                           14                          10
# 5                          267                         262
#
#     cafe_count_3000_price_2500  cafe_count_3000_price_4000  \
# id
# 1                            3                           1
# 2                            2                           1
# 3                            3                           1
# 4                            3                           0
# 5                          149                          57
#
#     cafe_count_3000_price_high  big_church_count_3000  church_count_3000  \
# id
# 1                            0                      2                  4
# 2                            0                      1                  7
# 3                            0                      0                 11
# 4                            0                      1                  2
# 5                            4                     70                121
#
#     mosque_count_3000  leisure_count_3000  sport_count_3000  \
# id
# 1                   0                   0                21
# 2                   0                   6                19
# 3                   0                   0                20
# 4                   0                   0                18
# 5                   1                  40                77
#
#     market_count_3000  green_part_5000  prom_part_5000  office_count_5000  \
# id
# 1                   1            13.09           13.31                 29
# 2                   1            10.26           27.47                 66
# 3                   6            13.69           21.58                 43
# 4                   3            14.18            3.89                  8
# 5                   5             8.38           10.92                689
#
#     office_sqm_5000  trc_count_5000  trc_sqm_5000  cafe_count_5000  \
# id
# 1            807385              52       4036616              152
# 2           2690465              40       2034942              177
# 3           1478160              35       1572990              122
# 4            244166              22        942180               61
# 5           8404624             114       3503058             2283
#
#     cafe_sum_5000_min_price_avg  cafe_sum_5000_max_price_avg  \
# id
# 1                        708.57                      1185.71
# 2                        673.81                      1148.81
# 3                        702.68                      1196.43
# 4                        931.58                      1552.63
# 5                        853.88                      1411.45
#
#     cafe_avg_price_5000  cafe_count_5000_na_price  cafe_count_5000_price_500  \
# id
# 1                947.14                        12                         39
# 2                911.31                         9                         49
# 3                949.55                        10                         29
# 4               1242.11                         4                          7
# 5               1132.66                       143                        566
#
#     cafe_count_5000_price_1000  cafe_count_5000_price_1500  \
# id
# 1                           48                          40
# 2                           65                          36
# 3                           45                          25
# 4                           21                          15
# 5                          578                         552
#
#     cafe_count_5000_price_2500  cafe_count_5000_price_4000  \
# id
# 1                            9                           4
# 2                           15                           3
# 3                           10                           3
# 4                           11                           2
# 5                          319                         108
#
#     cafe_count_5000_price_high  big_church_count_5000  church_count_5000  \
# id
# 1                            0                     13                 22
# 2                            0                     15                 29
# 3                            0                     11                 27
# 4                            1                      4                  4
# 5                           17                    135                236
#
#     mosque_count_5000  leisure_count_5000  sport_count_5000  \
# id
# 1                   1                   0                52
# 2                   1                  10                66
# 3                   0                   4                67
# 4                   0                   0                26
# 5                   2                  91               195
#
#     market_count_5000  price_doc
# id
# 1                   4    5850000
# 2                  14    6000000
# 3                  10    5700000
# 4                   3   13100000
# 5                  14   16331452

# %%
add_datepart(df_train, ['timestamp'])

# %%
discrete = [var for var in df_train.columns if df_train[var].dtype!='O' and var!='price_doc' and df_train[var].nunique()<10]
continuous = [var for var in df_train.columns if df_train[var].dtype!='O' and var!='price_doc' and var not in discrete]
categorical = [var for var in df_train.columns if df_train[var].dtype=='O']

# %%
df_train[discrete].astype('O')
# Out:
#       material state school_education_centers_top_20_raion  \
# id
# 1          NaN   NaN                                     0
# 2          NaN   NaN                                     0
# 3          NaN   NaN                                     0
# 4          NaN   NaN                                     0
# 5          NaN   NaN                                     0
# ...        ...   ...                                   ...
# 30469        1     3                                     0
# 30470        2     3                                     1
# 30471        1     1                                     0
# 30472        1     2                                     0
# 30473        1     2                                     0
#
#       healthcare_centers_raion university_top_20_raion  \
# id
# 1                            1                       0
# 2                            1                       0
# 3                            1                       0
# 4                            1                       0
# 5                            4                       2
# ...                        ...                     ...
# 30469                        1                       0
# 30470                        3                       2
# 30471                        0                       0
# 30472                        2                       1
# 30473                        2                       0
#
#       culture_objects_top_25_raion build_count_foam build_count_mix  \
# id
# 1                                0                0               0
# 2                                1                0               0
# 3                                0                0               0
# 4                                0                0               2
# 5                                0                0               1
# ...                            ...              ...             ...
# 30469                            0                0               0
# 30470                           10                0               1
# 30471                            0              NaN             NaN
# 30472                            0                0               0
# 30473                            0                0               0
#
#       ID_railroad_terminal trc_count_500 cafe_count_500_price_high  \
# id
# 1                      101             0                         0
# 2                       32             0                         0
# 3                        5             0                         0
# 4                       83             0                         0
# 5                      113             1                         0
# ...                    ...           ...                       ...
# 30469                  101             2                         0
# 30470                   83             0                         0
# 30471                   50             0                         0
# 30472                   32             0                         0
# 30473                    5             3                         0
#
#       mosque_count_500 market_count_500 cafe_count_1000_price_high  \
# id
# 1                    0                0                          0
# 2                    0                0                          0
# 3                    0                0                          0
# 4                    0                0                          0
# 5                    0                0                          1
# ...                ...              ...                        ...
# 30469                0                0                          0
# 30470                0                0                          1
# 30471                0                0                          0
# 30472                0                0                          0
# 30473                0                0                          0
#
#       mosque_count_1000 market_count_1000 mosque_count_1500 market_count_1500  \
# id
# 1                     0                 1                 0                 1
# 2                     0                 0                 0                 0
# 3                     0                 3                 0                 5
# 4                     0                 1                 0                 2
# 5                     0                 0                 0                 2
# ...                 ...               ...               ...               ...
# 30469                 0                 1                 0                 2
# 30470                 0                 0                 0                 1
# 30471                 0                 0                 0                 0
# 30472                 0                 0                 0                 0
# 30473                 0                 0                 0                 1
#
#       mosque_count_2000 market_count_2000 mosque_count_3000 mosque_count_5000  \
# id
# 1                     0                 1                 0                 1
# 2                     0                 0                 0                 1
# 3                     0                 5                 0                 0
# 4                     0                 2                 0                 0
# 5                     0                 3                 1                 2
# ...                 ...               ...               ...               ...
# 30469                 1                 3                 1                 1
# 30470                 0                 2                 1                 1
# 30471                 0                 0                 0                 0
# 30472                 0                 2                 1                 1
# 30473                 0                 2                 0                 0
#
#       timestamp_year timestamp_dayofweek timestamp_weekday timestamp_quarter  \
# id
# 1               2011                   5                 5                 3
# 2               2011                   1                 1                 3
# 3               2011                   5                 5                 3
# 4               2011                   3                 3                 3
# 5               2011                   0                 0                 3
# ...              ...                 ...               ...               ...
# 30469           2015                   1                 1                 2
# 30470           2015                   1                 1                 2
# 30471           2015                   1                 1                 2
# 30472           2015                   1                 1                 2
# 30473           2015                   1                 1                 2
#
#       timestamp_is_month_start timestamp_is_month_end timestamp_is_year_end
# id
# 1                        False                  False                 False
# 2                        False                  False                 False
# 3                        False                  False                 False
# 4                         True                  False                 False
# 5                        False                  False                 False
# ...                        ...                    ...                   ...
# 30469                    False                   True                 False
# 30470                    False                   True                 False
# 30471                    False                   True                 False
# 30472                    False                   True                 False
# 30473                    False                   True                 False
#
# [30471 rows x 29 columns]

# %%
df_train['ID_railroad_terminal'].unique()
# Out:
# array([101,  32,   5,  83, 113,  97, 121,  50], dtype=int64)

# %%
len(discrete), len(continuous), len(categorical)
# Out:
# (29, 255, 15)

# %%
 def split_val(df:pd.DataFrame, val_pct:float=0.3):
    'returns `df_train` and `df_valid`'
    shuf_idx=np.random.permutation(len(df))
    train_idx, val_idx=shuf_idx[int(val_pct*len(df)):], shuf_idx[:int(val_pct*len(df))]
    return df.iloc[train_idx,:], df.iloc[val_idx,:]
    
def split_dep_col(df:pd.DataFrame, y:str):
    'returns `x` and `y`'
    return df.drop(columns=y), df.loc[:, y]
    
def split_test_val(df:pd.DataFrame, y:str, val_pct:float=0.3):
    ''' df 'pandas datadrame object `y` is the dependent column val_pct:=0.3'
    returns `x_train`, `y_train`, `x_valid`, `y_valid`'''
    df_train, df_val= split_val(df, val_pct)
    return split_dep_col(df_train, y), split_dep_col(df_val, y)

# %%
(x_train, y_train), (x_val, y_val)= split_test_val(df_train, y='price_doc')

# %%
def add_datepart(df:pd.DataFrame, cols:list=None, just_date:bool=True,inplace:bool=True)->pd.DataFrame:
    date_part=['year','month','day','week','dayofweek','weekday','quarter','is_month_start','is_month_end','is_year_end']
    time_part=['time','hour','minute','second']
    for i in cols:
        if not just_date:
            for j in time_part:
                df[f'{i}_{j}']=getattr(df[i].dt,j)
        for j in date_part:
            df[f'{i}_{j}']=getattr(df[i].dt,j)
    df.drop(columns=cols, inplace=True)
    return

# %%
x_train.shape
# Out:
# (21330, 299)

# %%
def check_missing(df:pd.DataFrame, top:int=10):
    return pd.DataFrame(df.isna().mean()).sort_values(by=0, ascending=False)[:top]

# %%
check_missing(x_train[continuous])
# Out:
#                                    0
# hospital_beds_raion         0.473558
# build_year                  0.443976
# cafe_sum_500_min_price_avg  0.434224
# cafe_sum_500_max_price_avg  0.434224
# cafe_avg_price_500          0.434224
# max_floor                   0.312236
# num_room                    0.312236
# kitch_sq                    0.312236
# preschool_quota             0.219175
# school_quota                0.219081

# %%
x_cont_miss=check_missing(x_train[continuous])
cont_mis=list(x_cont_miss[x_cont_miss[0]>0].index)

# %%
check_missing(x_train[discrete])
# Out:
#                                  0
# state                     0.441163
# material                  0.312236
# build_count_foam          0.164229
# build_count_mix           0.164229
# mosque_count_1500         0.000000
# timestamp_is_month_end    0.000000
# timestamp_is_month_start  0.000000
# timestamp_quarter         0.000000
# timestamp_weekday         0.000000
# timestamp_dayofweek       0.000000

# %%
discrete_mis=['state','material','build_count_foam','build_count_mix']

# %%
check_missing(x_train[categorical])
# Out:
#                              0
# product_type               0.0
# sub_area                   0.0
# culture_objects_top_25     0.0
# thermal_power_plant_raion  0.0
# incineration_raion         0.0
# oil_chemistry_raion        0.0
# radiation_raion            0.0
# railroad_terminal_raion    0.0
# big_market_raion           0.0
# nuclear_reactor_raion      0.0

# %%
x_train
# Out:
#        full_sq  life_sq  floor  max_floor  material  build_year  num_room  \
# id
# 23911       57     37.0    8.0        8.0       2.0      1959.0       2.0
# 27206       72     32.0   10.0       17.0       1.0      2006.0       2.0
# 25819       38      NaN    5.0       22.0       4.0         NaN       1.0
# 30262       56     35.0    4.0       24.0       6.0      2017.0       2.0
# 7284        45     30.0    5.0        NaN       NaN         NaN       NaN
# ...        ...      ...    ...        ...       ...         ...       ...
# 14221       44     30.0    5.0        5.0       2.0      1959.0       2.0
# 10067       74     51.0   15.0        NaN       NaN         NaN       NaN
# 13295       39      NaN    2.0       17.0       1.0         NaN       1.0
# 12549       54     27.0    2.0        4.0       6.0      2015.0       2.0
# 10089       42      NaN   13.0        0.0       4.0         NaN       1.0
#
#        kitch_sq  state   product_type                  sub_area        area_m  \
# id
# 23911       9.0    3.0     Investment             Lomonosovskoe  3.326419e+06
# 27206      11.0    3.0     Investment          Kosino-Uhtomskoe  1.488362e+07
# 25819       1.0    1.0  OwnerOccupier         Nagatinskij Zaton  9.589337e+06
# 30262       8.0    1.0  OwnerOccupier         Nagatinskij Zaton  9.589337e+06
# 7284        NaN    NaN     Investment                 Kuz'minki  7.984444e+06
# ...         ...    ...            ...                       ...           ...
# 14221       5.0    2.0     Investment            Akademicheskoe  5.704502e+06
# 10067       NaN    NaN     Investment                Vojkovskoe  5.333221e+06
# 13295       1.0    NaN  OwnerOccupier      Poselenie Moskovskij  4.036700e+07
# 12549       6.0    1.0  OwnerOccupier  Poselenie Filimonkovskoe  3.574795e+07
# 10089       0.0    1.0  OwnerOccupier       Poselenie Sosenskoe  6.677245e+07
#
#        raion_popul  green_zone_part  indust_part  children_preschool  \
# id
# 23911        83844         0.051881     0.000000                4688
# 27206        72131         0.024444     0.158249                7567
# 25819       115352         0.372602     0.049637                6880
# 30262       115352         0.372602     0.049637                6880
# 7284        142243         0.372735     0.000995                7753
# ...            ...              ...          ...                 ...
# 14221       106445         0.043127     0.151346                5506
# 10067        64931         0.074077     0.169091                3905
# 13295        21819         0.492840     0.075779                1497
# 12549         2546         0.548992     0.034656                 175
# 10089         9553         0.336177     0.072158                 656
#
#        preschool_quota  preschool_education_centers_raion  children_school  \
# id
# 23911           3091.0                                  5             5027
# 27206           3848.0                                  4             5731
# 25819           3119.0                                  5             7759
# 30262           3119.0                                  5             7759
# 7284            4547.0                                  8             7651
# ...                ...                                ...              ...
# 14221            926.0                                  6             5889
# 10067           1579.0                                  6             3856
# 13295              NaN                                  0             1437
# 12549              NaN                                  0              168
# 10089              NaN                                  0              629
#
#        school_quota  school_education_centers_raion  \
# id
# 23911        8359.0                               7
# 27206        8687.0                               5
# 25819        6237.0                               8
# 30262        6237.0                               8
# 7284        10492.0                               8
# ...             ...                             ...
# 14221        9501.0                               6
# 10067        5838.0                               8
# 13295           NaN                               0
# 12549           NaN                               0
# 10089           NaN                               0
#
#        school_education_centers_top_20_raion  hospital_beds_raion  \
# id
# 23911                                      1                 46.0
# 27206                                      0                  NaN
# 25819                                      0                229.0
# 30262                                      0                229.0
# 7284                                       1                  NaN
# ...                                      ...                  ...
# 14221                                      0                830.0
# 10067                                      0                  NaN
# 13295                                      0                  NaN
# 12549                                      0                  NaN
# 10089                                      0                  NaN
#
#        healthcare_centers_raion  university_top_20_raion  sport_objects_raion  \
# id
# 23911                         1                        0                    6
# 27206                         1                        0                    4
# 25819                         1                        0                    6
# 30262                         1                        0                    6
# 7284                          1                        0                    7
# ...                         ...                      ...                  ...
# 14221                         4                        0                    7
# 10067                         2                        0                    5
# 13295                         0                        0                    3
# 12549                         0                        0                    0
# 10089                         0                        0                    1
#
#        additional_education_raion culture_objects_top_25  \
# id
# 23911                           4                     no
# 27206                           2                     no
# 25819                           1                    yes
# 30262                           1                    yes
# 7284                            8                     no
# ...                           ...                    ...
# 14221                           0                     no
# 10067                           2                     no
# 13295                           3                     no
# 12549                           0                     no
# 10089                           0                     no
#
#        culture_objects_top_25_raion  shopping_centers_raion  office_raion  \
# id
# 23911                             0                       1             4
# 27206                             0                       0             0
# 25819                             1                       3             0
# 30262                             1                       3             0
# 7284                              0                       5             1
# ...                             ...                     ...           ...
# 14221                             0                       1            10
# 10067                             0                       5            10
# 13295                             0                       2             3
# 12549                             0                       0             0
# 10089                             0                       0             1
#
#       thermal_power_plant_raion incineration_raion oil_chemistry_raion  \
# id
# 23911                        no                 no                  no
# 27206                        no                yes                  no
# 25819                        no                 no                  no
# 30262                        no                 no                  no
# 7284                         no                 no                  no
# ...                         ...                ...                 ...
# 14221                       yes                 no                  no
# 10067                        no                 no                  no
# 13295                        no                 no                  no
# 12549                        no                 no                  no
# 10089                        no                 no                  no
#
#       radiation_raion railroad_terminal_raion big_market_raion  \
# id
# 23911              no                      no               no
# 27206             yes                      no               no
# 25819              no                      no               no
# 30262              no                      no               no
# 7284              yes                      no               no
# ...               ...                     ...              ...
# 14221             yes                      no               no
# 10067              no                      no               no
# 13295              no                      no               no
# 12549              no                      no               no
# 10089              no                      no              yes
#
#       nuclear_reactor_raion detention_facility_raion  full_all  male_f  \
#
#        cafe_count_5000_price_500  cafe_count_5000_price_1000  \
# id
# 23911                         85                         118
# 27206                          8                          16
# 25819                         50                          62
# 30262                         50                          62
# 7284                          24                          35
# ...                          ...                         ...
# 14221                        134                         166
# 10067                         79                          81
# 13295                          2                           7
# 12549                          1                           1
# 10089                          1                           2
#
#        cafe_count_5000_price_1500  cafe_count_5000_price_2500  \
# id
# 23911                         111                          43
# 27206                          11                           1
# 25819                          40                          13
# 30262                          40                          13
# 7284                           25                           6
# ...                           ...                         ...
# 14221                         147                          68
# 10067                          57                          16
# 13295                           3                           1
# 12549                           1                           0
# 10089                           5                           2
#
#        cafe_count_5000_price_4000  cafe_count_5000_price_high  \
# id
# 23911                           8                           1
# 27206                           1                           0
# 25819                           3                           0
# 30262                           3                           0
# 7284                            2                           0
# ...                           ...                         ...
# 14221                          11                           2
# 10067                           5                           0
# 13295                           0                           0
# 12549                           0                           0
# 10089                           2                           0
#
#        big_church_count_5000  church_count_5000  mosque_count_5000  \
# id
# 23911                      7                 36                  1
# 27206                      5                  9                  0
# 25819                      9                 29                  0
# 30262                      9                 29                  0
# 7284                       6                 24                  0
# ...                      ...                ...                ...
# 14221                     31                 53                  1
# 10067                     11                 18                  0
# 13295                      1                  7                  0
# 12549                      0                  4                  0
# 10089                      1                 12                  1
#
#        leisure_count_5000  sport_count_5000  market_count_5000  \
# id
# 23911                   7                93                  6
# 27206                   2                17                  6
# 25819                   7                63                 13
# 30262                   7                63                 13
# 7284                    6                60                 11
# ...                   ...               ...                ...
# 14221                  18               108                 11
# 10067                   3                83                 12
# 13295                   0                 8                  0
# 12549                   0                 2                  0
# 10089                   0                 8                  0
#
#        timestamp_year  timestamp_month  timestamp_day  timestamp_week  \
# id
# 23911            2014               10             24              43
# 27206            2014               12             30               1
# 25819            2014               12              4              49
# 30262            2015                6             15              25
# 7284             2013                4             13              15
# ...               ...              ...            ...             ...
# 14221            2014                1             28               5
# 10067            2013                8             26              35
# 13295            2013               12             20              51
# 12549            2013               11             27              48
# 10089            2013                8             27              35
#
#        timestamp_dayofweek  timestamp_weekday  timestamp_quarter  \
# id
# 23911                    4                  4                  4
# 27206                    1                  1                  4
# 25819                    3                  3                  4
# 30262                    0                  0                  2
# 7284                     5                  5                  2
# ...                    ...                ...                ...
# 14221                    1                  1                  1
# 10067                    0                  0                  3
# 13295                    4                  4                  4
# 12549                    2                  2                  4
# 10089                    1                  1                  3
#
#        timestamp_is_month_start  timestamp_is_month_end  timestamp_is_year_end
# id
# 23911                     False                   False                  False
# 27206                     False                   False                  False
# 25819                     False                   False                  False
# 30262                     False                   False                  False
# 7284                      False                   False                  False
# ...                         ...                     ...                    ...
# 14221                     False                   False                  False
# 10067                     False                   False                  False
# 13295                     False                   False                  False
# 12549                     False                   False                  False
# 10089                     False                   False                  False
#
# [21330 rows x 299 columns]

# %%
df_train.groupby('timestamp_month')['price_doc'].median().plot()
plt.title('House price variation in the year')
plt.ylabel('mean House price')
# Out:
# Text(0, 0.5, 'mean House price')

# %%
len(discrete), len(categorical)
# Out:
# (29, 15)

# %%
x_train[discrete+categorical]= x_train[discrete+categorical].astype('category')
x_val[discrete+categorical] = x_val[discrete+categorical].astype('category')

# %%
x_train['state'].cat.codes
# Out:
# id
# 6413    -1
# 12562   -1
# 25747    2
# 22316    0
# 15944    3
#         ..
# 5864    -1
# 4902    -1
# 17756   -1
# 5135    -1
# 644     -1
# Length: 21330, dtype: int8

# %%
numerical = [var for var in df_train.columns if df_train[var].dtype!='O']
numerical = [var for var in numerical if var not in discrete and var not in ['price_doc']]

# %%
pipe = Pipeline([

    # missing data imputation - section 4
    ('missing_ind', mdi.AddNaNBinaryImputer(
        variables=discrete_mis+cont_mis)),
    ('imputer_num', mdi.MeanMedianImputer(imputation_method='mean',
                                          variables=continuous)),
    ('imputer_cat', mdi.CategoricalVariableImputer(variables=discrete)),

    # categorical encoding - section 6
    ('rare_label_enc', ce.RareLabelCategoricalEncoder(
        tol=0.05, n_categories=6, variables=categorical+discrete)),
    ('categorical_enc', ce.OrdinalCategoricalEncoder(
        encoding_method='ordered', variables=categorical+discrete)),

    # discretisation + encoding
    ('discretisation', dsc.EqualFrequencyDiscretiser(
        q=5, return_object=True, variables=numerical)),
    ('encoding', ce.OrdinalCategoricalEncoder(
        encoding_method='ordered', variables=numerical)),

    # feature Scaling
    ('scaler', StandardScaler()),
    
    # regression
    ('lasso', Lasso(random_state=0))
])

# %%
x_train_preds=pipe.fit(x_train)
x_val_preds=pipe.fit(x_val)

# %%
class Tabular:
    def __init__(self, df_train:pd.DataFrame, df_val:pd.DataFrame , cat_cols:list=[], num_cols:list=[]):
        self.df_train=df_train
        self.df_val=df_val
        self.cat_cols=cat_cols
        self.num_cols=num_cols
        self.cat_col_dict={}
        self.rev_cat={}
        
    def conv_cat(self):
        for i in self.cat_cols:
            self.cat_col_dict[i]={k: j for j, k in enumerate(self.df_train[i].unique())}
            self.df_train[i].replace(self.cat_col_dict[i])
            self.df_val[i].replace(self.cat_col_dict[i])
            
    def impute_mean(self):
        self.mean_impute_dict={}
        for i in self.num_cols:
            self.mean_impute_dict[i]=self.df_train[i].mean()
            self.impute_na(self.df_train, i, self.mean_impute_dict[i])
            self.impute_na(self.df_val, i, self.mean_impute_dict[i])
            
    def impute_median(self):
        self.median_impute_dict={}
        for i in self.num_cols:
            self.median_impute_dict[i]=self.df_train[i].median()
            self.impute_na(self.df_train, i, self.median_impute_dict[i])
            self.impute_na(self.df_val, i, self.median_impute_dict[i])
            
    def impute_na(self, df:pd.DataFrame, col:str, value):
        df[col].fillna(value, inplace=True)
            
    def encode_disc(self):
        for i in self.dis_cols:
            df[i]=pd.qcut(df[i], 4)
    
    def rep_cat_codes(self):
#         self.rev_cat=dict(map(reversed, self.cat_col_dict[i]))
        for i in self.cat_cols:
#             temp=dict(map(reversed, self.cat_col_dict[i]))
            self.df_train[i].replace(self.cat_col_dict[i], inplace=True)
            self.impute_na(self.df_train, i, -1)
            self.df_val[i].replace(self.cat_col_dict[i], inplace=True) # dict(map(reversed, my_map.items()))
            self.impute_na(self.df_val, i, -1)

# %%
def proc_df(df_tr:pd.DataFrame, df_va:pd.DataFrame, cat_cols:list, num_cols:list):
    data=Tabular(df_tr, df_va, cat_cols=cat_cols, num_cols=num_cols)
    data.impute_mean()
    data.conv_cat()
    data.rep_cat_codes()
    return data

# %%
data=proc_df(x_train, x_val, cat_cols=categorical+discrete, num_cols=continuous)

# %%
X_train, X_val=norm_max_min(data.df_train, data.df_val)

# %%
def norm_max_min(df_train, df_val):
    res_train, res_val = df_train.copy(), df_val.copy()
    for feature_name in df_train.columns:
        max_value = df_train[feature_name].max()
        min_value = df_train[feature_name].min()
        res_train[feature_name] = (df_train[feature_name] - min_value) / (max_value - min_value)
        res_val[feature_name]= (df_val[feature_name]-min_value/ (max_value-min_value))
    return res_train, res_val

# %%
def normalize(df_train, df_val):
    res_train, res_val= df_train.copy(), data.df_val.copy()
    for feature_name in res_train.columns:
        mean_train=res_train[feature_name].mean()
        std_train=res_train[feature_name].std
        res_train[feature_name]=(res_train[feature_name]-mean_train)/std_train
        res_val[feature_name]=(res_val[feature_name]-mean_train)/std_train
    return res_train, res_val

# %%
clf = Lasso(alpha=1, max_iter=100000)
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-291-bca83dbe7551> in <module>
#       1 clf = Lasso(alpha=1, max_iter=100000)
# ----> 2 clf.fit(X_train, y_train)
#
# D:\narain\anaconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py in fit(self, X, y, check_input)
#     749                           random_state=self.random_state,
#     750                           selection=self.selection,
# --> 751                           check_input=False)
#     752             coef_[k] = this_coef[:, 0]
#     753             dual_gaps_[k] = this_dual_gap[0]
#
# D:\narain\anaconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py in enet_path(X, y, l1_ratio, eps, n_alphas, alphas, precompute, Xy, copy_X, coef_init, verbose, return_n_iter, positive, check_input, **params)
#     474             model = cd_fast.enet_coordinate_descent(
#     475                 coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random,
# --> 476                 positive)
#     477         else:
#     478             raise ValueError("Precompute should be one of True, False, "
#
# sklearn\linear_model\_cd_fast.pyx in sklearn.linear_model._cd_fast.enet_coordinate_descent()
#
# KeyboardInterrupt:

# %%
preds=clf.predict(X_val)

# %%
r2_score(y_val, preds)

# %%
y_val[:10], preds[:10]
# Out:
# (id
#  7726     12640380
#  14920    20500000
#  18669    14000000
#  22009     7000000
#  29603     1000000
#  25546     4641000
#  23814     5756303
#  9332      6500000
#  13947     5400000
#  3653      5500000
#  Name: price_doc, dtype: int64,
#  array([ 6.77124275e+11,  3.59635378e+12,  2.91997679e+12,  9.68110173e+11,
#          4.52550836e+12,  3.89481513e+10, -2.41197086e+10,  4.78898501e+12,
#          4.06917335e+12,  3.33473077e+11]))

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regr = RandomForestRegressor(max_depth=3, random_state=0)
regr.fit(X_train, y_train)
preds=regr.predict(X_val)
r2_score(y_val, preds)
# Out:
# -26.1997974514665

# %%
y_val[:10], preds[:10]
# Out:
# (id
#  7726     12640380
#  14920    20500000
#  18669    14000000
#  22009     7000000
#  29603     1000000
#  25546     4641000
#  23814     5756303
#  9332      6500000
#  13947     5400000
#  3653      5500000
#  Name: price_doc, dtype: int64,
#  array([33595172.90340298, 33595172.90340298, 33595172.90340298,
#         32955842.97149104, 31824090.21802514, 28483994.76756088,
#         11264449.11355723, 33595172.90340298, 32838501.25733667,
#         31824090.21802514]))

# %%
preds.std()
# Out:
# 5267567.857889471
