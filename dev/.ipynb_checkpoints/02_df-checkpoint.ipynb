# %%
# %matplotlib inline

# %%
#export
from export.nb_01 import *
import pandas as pd
import numpy as np
from pandas.api.types import is_string_dtype, is_numeric_dtype, is_categorical_dtype
import matplotlib.pyplot as plt
import os
from collections import OrderedDict
from typing import Tuple

pd.pandas.set_option('display.max_columns', None)

# %%
#export
Path.ls= lambda x: [i.name for i in os.scandir()]

# %%
path_tabdata=Path(r'D:\datasets\new_datasets')
path_tabdata.ls()
# Out:
# ['.ipynb_checkpoints',
#  '00_testing.ipynb',
#  '01_nn.ipynb',
#  '02b_tabular.ipynb',
#  '02_callbacks.ipynb',
#  '02_df.ipynb',
#  '03_dataloader.ipynb',
#  '04_transforms.ipynb',
#  'callback_dev.ipynb',
#  'export',
#  'notebook2script.py']

# %%
path_house=path_tabdata/'sberbank-russian-housing-market'
path_house.ls()
# Out:
# ['.ipynb_checkpoints',
#  '00_testing.ipynb',
#  '01_nn.ipynb',
#  '02b_tabular.ipynb',
#  '02_callbacks.ipynb',
#  '02_df.ipynb',
#  '03_dataloader.ipynb',
#  '04_transforms.ipynb',
#  'callback_dev.ipynb',
#  'export',
#  'notebook2script.py']

# %%
path_house_train=path_house/'train.csv'
path_house_test=path_house/'test.csv'

# %%
df=pd.read_csv(path_house_train, index_col='id', parse_dates=['timestamp'], infer_datetime_format=True)
df.head()
# Out:
#     timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# id
# 1  2011-08-20       43     27.0    4.0        NaN       NaN         NaN
# 2  2011-08-23       34     19.0    3.0        NaN       NaN         NaN
# 3  2011-08-27       43     29.0    2.0        NaN       NaN         NaN
# 4  2011-09-01       89     50.0    9.0        NaN       NaN         NaN
# 5  2011-09-05       77     77.0    4.0        NaN       NaN         NaN
#
#     num_room  kitch_sq  state product_type           sub_area        area_m  \
# id
# 1        NaN       NaN    NaN   Investment           Bibirevo  6.407578e+06
# 2        NaN       NaN    NaN   Investment  Nagatinskij Zaton  9.589337e+06
# 3        NaN       NaN    NaN   Investment     Tekstil'shhiki  4.808270e+06
# 4        NaN       NaN    NaN   Investment             Mitino  1.258354e+07
# 5        NaN       NaN    NaN   Investment          Basmannoe  8.398461e+06
#
#     raion_popul  green_zone_part  indust_part  children_preschool  \
# id
# 1        155572         0.189727     0.000070                9576
# 2        115352         0.372602     0.049637                6880
# 3        101708         0.112560     0.118537                5879
# 4        178473         0.194703     0.069753               13087
# 5        108171         0.015234     0.037316                5706
#
#     preschool_quota  preschool_education_centers_raion  children_school  \
# id
# 1            5001.0                                  5            10309
# 2            3119.0                                  5             7759
# 3            1463.0                                  4             6207
# 4            6839.0                                  9            13670
# 5            3240.0                                  7             6748
#
#     school_quota  school_education_centers_raion  \
# id
# 1        11065.0                               5
# 2         6237.0                               8
# 3         5580.0                               7
# 4        17063.0                              10
# 5         7770.0                               9
#
#     school_education_centers_top_20_raion  hospital_beds_raion  \
# id
# 1                                       0                240.0
# 2                                       0                229.0
# 3                                       0               1183.0
# 4                                       0                  NaN
# 5                                       0                562.0
#
#     healthcare_centers_raion  university_top_20_raion  sport_objects_raion  \
# id
# 1                          1                        0                    7
# 2                          1                        0                    6
# 3                          1                        0                    5
# 4                          1                        0                   17
# 5                          4                        2                   25
#
#     additional_education_raion culture_objects_top_25  \
# id
# 1                            3                     no
# 2                            1                    yes
# 3                            1                     no
# 4                            6                     no
# 5                            2                     no
#
#     culture_objects_top_25_raion  shopping_centers_raion  office_raion  \
# id
# 1                              0                      16             1
# 2                              1                       3             0
# 3                              0                       0             1
# 4                              0                      11             4
# 5                              0                      10            93
#
#    thermal_power_plant_raion incineration_raion oil_chemistry_raion  \
# id
# 1                         no                 no                  no
# 2                         no                 no                  no
# 3                         no                 no                  no
# 4                         no                 no                  no
# 5                         no                 no                  no
#
#    radiation_raion railroad_terminal_raion big_market_raion  \
# id
# 1               no                      no               no
# 2               no                      no               no
# 3              yes                      no               no
# 4               no                      no               no
# 5              yes                     yes               no
#
#    nuclear_reactor_raion detention_facility_raion  full_all  male_f  female_f  \
# id
# 1                     no                       no     86206   40477     45729
# 2                     no                       no     76284   34200     42084
# 3                     no                       no    101982   46076     55906
# 4                     no                       no     21155    9828     11327
# 5                     no                       no     28179   13522     14657
#
#     young_all  young_male  young_female  work_all  work_male  work_female  \
# id
# 1       21154       11007         10147     98207      52277        45930
# 2       15727        7925          7802     70194      35622        34572
# 3       13028        6835          6193     63388      31813        31575
# 4       28563       14680         13883    120381      60040        60341
# 5       13368        7159          6209     68043      34236        33807
#
#     ekder_all  ekder_male  ekder_female  0_6_all  0_6_male  0_6_female  \
# id
# 1       36211       10580         25631     9576      4899        4677
# 2       29431        9266         20165     6880      3466        3414
# 3       25292        7609         17683     5879      3095        2784
# 4       29529        9083         20446    13087      6645        6442
# 5       26760        8563         18197     5706      2982        2724
#
#     7_14_all  7_14_male  7_14_female  0_17_all  0_17_male  0_17_female  \
# id
# 1      10309       5463         4846     23603      12286        11317
# 2       7759       3909         3850     17700       8998         8702
# 3       6207       3269         2938     14884       7821         7063
# 4      13670       7126         6544     32063      16513        15550
# 5       6748       3664         3084     15237       8113         7124
#
#     16_29_all  16_29_male  16_29_female  0_13_all  0_13_male  0_13_female  \
# id
# 1       17508        9425          8083     18654       9709         8945
# 2       15164        7571          7593     13729       6929         6800
# 3       19401        9045         10356     11252       5916         5336
# 4        3292        1450          1842     24934      12782        12152
# 5        5164        2583          2581     11631       6223         5408
#
#     raion_build_count_with_material_info  build_count_block  build_count_wood  \
# id
# 1                                  211.0               25.0               0.0
# 2                                  245.0               83.0               1.0
# 3                                  330.0               59.0               0.0
# 4                                  458.0                9.0              51.0
# 5                                  746.0               48.0               0.0
#
#     build_count_frame  build_count_brick  build_count_monolith  \
# id
# 1                 0.0                0.0                   2.0
# 2                 0.0               67.0                   4.0
# 3                 0.0              206.0                   4.0
# 4                12.0              124.0                  50.0
# 5                 0.0              643.0                  16.0
#
#     build_count_panel  build_count_foam  build_count_slag  build_count_mix  \
# id
# 1               184.0               0.0               0.0              0.0
# 2                90.0               0.0               0.0              0.0
# 3                60.0               0.0               1.0              0.0
# 4               201.0               0.0               9.0              2.0
# 5                35.0               0.0               3.0              1.0
#
#     raion_build_count_with_builddate_info  build_count_before_1920  \
# id
# 1                                   211.0                      0.0
# 2                                   244.0                      1.0
# 3                                   330.0                      1.0
# 4                                   459.0                     13.0
# 5                                   746.0                    371.0
#
#     build_count_1921-1945  build_count_1946-1970  build_count_1971-1995  \
# id
# 1                     0.0                    0.0                  206.0
# 2                     1.0                  143.0                   84.0
# 3                     0.0                  246.0                   63.0
# 4                    24.0                   40.0                  130.0
# 5                   114.0                  146.0                   62.0
#
#     build_count_after_1995  ID_metro  metro_min_avto  metro_km_avto  \
# id
# 1                      5.0         1        2.590241       1.131260
# 2                     15.0         2        0.936700       0.647337
# 3                     20.0         3        2.120999       1.637996
# 4                    252.0         4        1.489049       0.984537
# 5                     53.0         5        1.257186       0.876620
#
#     metro_min_walk  metro_km_walk  kindergarten_km  school_km   park_km  \
ospice_morgue_km  detention_facility_km  public_healthcare_km  \
# id
# 1            2.392353               4.248036              0.974743
# 2            2.543747              12.649879              1.477723
# 3            0.621357               7.682303              0.097144
# 4            3.549558               8.789894              2.163735
# 5            1.864637               3.779781              1.121703
#
#     university_km  workplaces_km  shopping_centers_km  office_km  \
# id
# 1        6.715026       0.884350             0.648488   0.637189
# 2        1.852560       0.686252             0.519311   0.688796
# 3        0.841254       1.510089             1.486533   1.543049
# 4       10.903161       0.622272             0.599914   0.934273
# 5        0.991683       0.892668             0.429052   0.077901
#
#     additional_education_km  preschool_km  big_church_km  church_synagogue_km  \
# id
# 1                  0.947962      0.177975       0.625783             0.628187
# 2                  1.072315      0.273345       0.967821             0.471447
# 3                  0.391957      0.158072       3.178751             0.755946
# 4                  0.892674      0.236455       1.031777             1.561505
# 5                  0.810801      0.376838       0.378756             0.121681
#
#     mosque_km  theater_km  museum_km  exhibition_km  catering_km    ecology  \
# id
# 1    3.932040   14.053047   7.389498       7.023705     0.516838       good
# 2    4.841544    6.829889   0.709260       2.358840     0.230287  excellent
# 3    7.922152    4.273200   3.156423       4.958214     0.190462       poor
# 4   15.300449   16.990677  16.041521       5.029696     0.465820       good
# 5    2.584370    1.112486   1.800125       1.339652     0.026102  excellent
#
#     green_part_500  prom_part_500  office_count_500  office_sqm_500  \
# id
# 1             0.00           0.00                 0               0
# 2            25.14           0.00                 0               0
# 3             1.67           0.00                 0               0
# 4            17.36           0.57                 0               0
# 5             3.56           4.44                15          293699
#
#     trc_count_500  trc_sqm_500  cafe_count_500  cafe_sum_500_min_price_avg  \
# id
# 1               0            0               0                         NaN
# 2               0            0               5                      860.00
# 3               0            0               3                      666.67
# 4               0            0               2                     1000.00
# 5               1        45000              48                      702.22
#
#     cafe_sum_500_max_price_avg  cafe_avg_price_500  cafe_count_500_na_price  \
# id
# 1                          NaN                 NaN                        0
# 2                      1500.00             1180.00                        0
# 3                      1166.67              916.67                        0
# 4                      1500.00             1250.00                        0
# 5                      1166.67              934.44                        3
#
#     cafe_count_500_price_500  cafe_count_500_price_1000  \
# id
# 1                          0                          0
# 2                          1                          3
# 3                          0                          2
# 4                          0                          0
# 5                         17                         10
#
#     cafe_count_500_price_1500  cafe_count_500_price_2500  \
# id
# 1                           0                          0
# 2                           0                          0
# 3                           1                          0
# 4                           2                          0
# 5                          11                          7
#
#     cafe_count_500_price_4000  cafe_count_500_price_high  \
# id
# 1                           0                          0
# 2                           1                          0
# 3                           0                          0
# 4                           0                          0
# 5                           0                          0
#
#     big_church_count_500  church_count_500  mosque_count_500  \
# id
# 1                      0                 0                 0
# 2                      0                 1                 0
# 3                      0                 0                 0
# 4                      0                 0                 0
# 5                      1                 4                 0
#
#     leisure_count_500  sport_count_500  market_count_500  green_part_1000  \
# id
# 1                   0                1                 0             7.36
# 2                   0                0                 0            26.66
# 3                   0                0                 0             4.99
# 4                   0                0                 0            19.25
# 5                   2                3                 0             3.34
#
#     prom_part_1000  office_count_1000  office_sqm_1000  trc_count_1000  \
# id
# 1             0.00                  1            30500               3
# 2             0.07                  2            86600               5
# 3             0.29                  0                0               0
# 4            10.35                  1            11000               6
# 5             8.29                 46           420952               3
#
#     trc_sqm_1000  cafe_count_1000  cafe_sum_1000_min_price_avg  \
# id
# 1          55600               19                       527.78
# 2          94065               13                       615.38
# 3              0                9                       642.86
# 4          80780               12                       658.33
# 5         158200              153                       763.45
#
#     cafe_sum_1000_max_price_avg  cafe_avg_price_1000  \
# id
# 1                        888.89               708.33
# 2                       1076.92               846.15
# 3                       1142.86               892.86
# 4                       1083.33               870.83
# 5                       1272.41              1017.93
#
#     cafe_count_1000_na_price  cafe_count_1000_price_500  \
# id
# 1                          1                         10
# 2                          0                          5
# 3                          2                          0
# 4                          0                          3
# 5                          8                         39
#
#     cafe_count_1000_price_1000  cafe_count_1000_price_1500  \
# id
# 1                            4                           3
# 2                            6                           1
# 3                            5                           2
# 4                            4                           5
# 5                           45                          39
#
#     cafe_count_1000_price_2500  cafe_count_1000_price_4000  \
# id
# 1                            1                           0
# 2                            0                           1
# 3                            0                           0
# 4                            0                           0
# 5                           19                           2
#
#     cafe_count_1000_price_high  big_church_count_1000  church_count_1000  \
# id
# 1                            0                      1                  2
# 2                            0                      1                  2
# 3                            0                      0                  1
# 4                            0                      0                  0
# 5                            1                      7                 12
#
#     mosque_count_1000  leisure_count_1000  sport_count_1000  \
# id
# 1                   0                   0                 6
# 2                   0                   4                 2
# 3                   0                   0                 5
# 4                   0                   0                 3
# 5                   0                   6                 7
#
#     market_count_1000  green_part_1500  prom_part_1500  office_count_1500  \
# id
# 1                   1            14.27            6.92                  3
# 2                   0            21.53            7.71                  3
# 3                   3             9.92            6.73                  0
# 4                   1            28.38            6.57                  2
# 5                   0             4.12            4.83                 93
#
#     office_sqm_1500  trc_count_1500  trc_sqm_1500  cafe_count_1500  \
# id
# 1             39554               9        171420               34
# 2            102910               7        127065               17
# 3                 0               1          2600               14
# 4             11000               7         89492               23
# 5           1195735               9        445900              272
#
#     cafe_sum_1500_min_price_avg  cafe_sum_1500_max_price_avg  \
# id
# 1                        566.67                       969.70
# 2                        694.12                      1205.88
# 3                        516.67                       916.67
# 4                        673.91                      1130.43
# 5                        766.80                      1272.73
#
#     cafe_avg_price_1500  cafe_count_1500_na_price  cafe_count_1500_price_500  \
# id
# 1                768.18                         1                         14
# 2                950.00                         0                          6
# 3                716.67                         2                          4
# 4                902.17                         0                          5
# 5               1019.76                        19                         70
#
#     cafe_count_1500_price_1000  cafe_count_1500_price_1500  \
# id
# 1                           11                           6
# 2                            7                           1
# 3                            6                           2
# 4                            9                           8
# 5                           74                          72
#
#     cafe_count_1500_price_2500  cafe_count_1500_price_4000  \
# id
# 1                            2                           0
# 2                            2                           1
# 3                            0                           0
# 4                            1                           0
# 5                           30                           6
#
#     cafe_count_1500_price_high  big_church_count_1500  church_count_1500  \
# id
# 1                            0                      1                  2
# 2                            0                      1                  5
# 3                            0                      0                  4
# 4                            0                      1                  0
# 5                            1                     18                 30
#
#     mosque_count_1500  leisure_count_1500  sport_count_1500  \
# id
# 1                   0                   0                 7
# 2                   0                   4                 9
# 3                   0                   0                 6
# 4                   0                   0                 9
# 5                   0                  10                14
#
#     market_count_1500  green_part_2000  prom_part_2000  office_count_2000  \
# id
# 1                   1            11.77           15.97                  9
# 2                   0            22.37           19.25                  4
# 3                   5            12.99           12.75                  4
# 4                   2            32.29            5.73                  2
# 5                   2             4.53            5.02                149
#
#     office_sqm_2000  trc_count_2000  trc_sqm_2000  cafe_count_2000  \
# id
# 1            188854              19       1244891               36
# 2            165510               8        179065               21
# 3            100200               7         52550               24
# 4             11000               7         89492               25
# 5           1625130              17        564843              483
#
#     cafe_sum_2000_min_price_avg  cafe_sum_2000_max_price_avg  \
# id
# 1                        614.29                      1042.86
# 2                        695.24                      1190.48
# 3                        563.64                       977.27
# 4                        660.00                      1120.00
# 5                        765.93                      1269.23
#
#     cafe_avg_price_2000  cafe_count_2000_na_price  cafe_count_2000_price_500  \
# id
# 1                828.57                         1                         15
# 2                942.86                         0                          7
# 3                770.45                         2                          8
# 4                890.00                         0                          5
# 5               1017.58                        28                        130
#
#     cafe_count_2000_price_1000  cafe_count_2000_price_1500  \
# id
# 1                           11                           6
# 2                            8                           3
# 3                            9                           4
# 4                           11                           8
# 5                          129                         131
#
#     cafe_count_2000_price_2500  cafe_count_2000_price_4000  \
# id
# 1                            2                           1
# 2                            2                           1
# 3                            1                           0
# 4                            1                           0
# 5                           50                          14
#
#     cafe_count_2000_price_high  big_church_count_2000  church_count_2000  \
# id
# 1                            0                      1                  2
# 2                            0                      1                  5
# 3                            0                      0                  4
# 4                            0                      1                  1
# 5                            1                     35                 61
#
#     mosque_count_2000  leisure_count_2000  sport_count_2000  \
# id
# 1                   0                   0                10
# 2                   0                   4                11
# 3                   0                   0                 8
# 4                   0                   0                13
# 5                   0                  17                21
#
#     market_count_2000  green_part_3000  prom_part_3000  office_count_3000  \
# id
# 1                   1            11.98           13.55                 12
# 2                   0            18.07           27.32                 12
# 3                   5            12.14           26.46                  8
# 4                   2            20.79            3.57                  4
# 5                   3             5.06            8.62                305
#
#     office_sqm_3000  trc_count_3000  trc_sqm_3000  cafe_count_3000  \
# id
# 1            251554              23       1419204               68
# 2            821986              14        491565               30
# 3            110856               7         52550               41
# 4            167000              12        205756               32
# 5           3420907              60       2296870             1068
#
#     cafe_sum_3000_min_price_avg  cafe_sum_3000_max_price_avg  \
# id
# 1                        639.68                      1079.37
# 2                        631.03                      1086.21
# 3                        697.44                      1192.31
# 4                        718.75                      1218.75
# 5                        853.03                      1410.45
#
#     cafe_avg_price_3000  cafe_count_3000_na_price  cafe_count_3000_price_500  \
# id
# 1                859.52                         5                         21
# 2                858.62                         1                         11
# 3                944.87                         2                          9
# 4                968.75                         0                          5
# 5               1131.74                        63                        266
#
#     cafe_count_3000_price_1000  cafe_count_3000_price_1500  \
# id
# 1                           22                          16
# 2                           11                           4
# 3                           17                           9
# 4                           14                          10
# 5                          267                         262
#
#     cafe_count_3000_price_2500  cafe_count_3000_price_4000  \
# id
# 1                            3                           1
# 2                            2                           1
# 3                            3                           1
# 4                            3                           0
# 5                          149                          57
#
#     cafe_count_3000_price_high  big_church_count_3000  church_count_3000  \
# id
# 1                            0                      2                  4
# 2                            0                      1                  7
# 3                            0                      0                 11
# 4                            0                      1                  2
# 5                            4                     70                121
#
#     mosque_count_3000  leisure_count_3000  sport_count_3000  \
# id
# 1                   0                   0                21
# 2                   0                   6                19
# 3                   0                   0                20
# 4                   0                   0                18
# 5                   1                  40                77
#
#     market_count_3000  green_part_5000  prom_part_5000  office_count_5000  \
# id
# 1                   1            13.09           13.31                 29
# 2                   1            10.26           27.47                 66
# 3                   6            13.69           21.58                 43
# 4                   3            14.18            3.89                  8
# 5                   5             8.38           10.92                689
#
#     office_sqm_5000  trc_count_5000  trc_sqm_5000  cafe_count_5000  \
# id
# 1            807385              52       4036616              152
# 2           2690465              40       2034942              177
# 3           1478160              35       1572990              122
# 4            244166              22        942180               61
# 5           8404624             114       3503058             2283
#
#     cafe_sum_5000_min_price_avg  cafe_sum_5000_max_price_avg  \
# id
# 1                        708.57                      1185.71
# 2                        673.81                      1148.81
# 3                        702.68                      1196.43
# 4                        931.58                      1552.63
# 5                        853.88                      1411.45
#
#     cafe_avg_price_5000  cafe_count_5000_na_price  cafe_count_5000_price_500  \
# id
# 1                947.14                        12                         39
# 2                911.31                         9                         49
# 3                949.55                        10                         29
# 4               1242.11                         4                          7
# 5               1132.66                       143                        566
#
#     cafe_count_5000_price_1000  cafe_count_5000_price_1500  \
# id
# 1                           48                          40
# 2                           65                          36
# 3                           45                          25
# 4                           21                          15
# 5                          578                         552
#
#     cafe_count_5000_price_2500  cafe_count_5000_price_4000  \
# id
# 1                            9                           4
# 2                           15                           3
# 3                           10                           3
# 4                           11                           2
# 5                          319                         108
#
#     cafe_count_5000_price_high  big_church_count_5000  church_count_5000  \
# id
# 1                            0                     13                 22
# 2                            0                     15                 29
# 3                            0                     11                 27
# 4                            1                      4                  4
# 5                           17                    135                236
#
#     mosque_count_5000  leisure_count_5000  sport_count_5000  \
# id
# 1                   1                   0                52
# 2                   1                  10                66
# 3                   0                   4                67
# 4                   0                   0                26
# 5                   2                  91               195
#
#     market_count_5000  price_doc
# id
# 1                   4    5850000
# 2                  14    6000000
# 3                  10    5700000
# 4                   3   13100000
# 5                  14   16331452

# %%
#export
def get_sample(df: pd.DataFrame, n:int)-> pd.DataFrame:
    idxs= sorted(np.random.permutation(len(df))[:n])
    return df.iloc[idxs].copy()

# %%
def train_cats(df:pd.DataFrame):
    for col_name, col in df.items():
        if is_string_dtype(col):
            df[col_name]=col.astype('category').cat.as_ordered()

# %%
def apply_cats(df:pd.DataFrame, df_train:pd.DataFrame):
    for col_name, col in df.items():
        if (col_name in df_train.columns) and (df_train[col_name].dtype.name=='category'):
            df[col_name]=pd.Categorical(col, categories=df_train[col_name].cat.categories, ordered=True)

# %%
def fill_missing(df:pd.DataFrame, col_name: str, na_dict:dict=None):
    na_dict=() if na_dict is None else na_dict
    col=df[col_name]
    if is_numeric_dtype(col) and (pd.isnull(col).sum() or (col_name in na_dict)):
        df[col_name+'_na']=pd.isnull(col)
        filler=na_dict[col_name] if col_name in na_dict else col.median()
        df[col_name]=col.fillna(filler)
        na_dict[col_name]=filler
    return na_dict

# %%
def numericalize(df:pd.DataFrame, col_name, max_n_cat=-1, nans_to_zero=True):
    col=df[col_name]
    if not is_numeric_dtype(col) and len(col.cat.categories)> max_n_cat:
        df[col_name]=col.cat.codes
        if nans_to_zero:
            df[col_name]+=1

# %%
def proc_df(df:pd.DataFrame, y_fld:str=None,
           na_dict:dict=None, skip_flds:list=None, 
           ignore_flds:list=None, max_n_cat: int=-1):
    '''
    returns df, y, na_dict
    '''
    if skip_flds is None: skip_flds=[]
    if ignore_flds is None: ignore_flds=[]
    if na_dict is None: na_dict={}
        
    assert sum(1 if not (is_categorical_dtype(df[col_name])) or
            is_numeric_dtype(df[col_name]) else 0
              for col_name in df.columns), 'all the columns in the df must be of type numerical or categorical'
    df = df.copy()
    ignored_cols = df.loc[:, ignore_flds]
    df.drop(ignore_flds, axis=1, inplace=True)
    y=None
    if y_fld:
        if not is_numeric_dtype(df[y_fld]):
            df[y_fld]= df[y_fld].cat.codes
        y=df[y_fld].values
        skip_flds.append(y_fld)
        
    df.drop(skip_flds, axis=1, inplace=True)
    for col_name in df.columns:
        fill_missing(df, col_name, na_dict)
        numericalize(df, col_name, max_n_cat=max_n_cat)
        
    df = pd.get_dummies(df, dummy_na=True)
    df=pd.concat([ignored_cols, df], axis=1)
    return df, y, na_dict

# %%
#export
def add_datepart(df:pd.DataFrame, cols:list=None, time:bool=True,inplace:bool=True)->pd.DataFrame:
    '''parameters:
                df: pd.DataFrame
                cols: datetime cols
                just date: bool specifying whether the object is it just date or date time
                inplace: bool'''
    date_part=['year','month','day','week','dayofweek','weekday','quarter','is_month_start','is_month_end','is_year_end']
    time_part=['hour','minute','second']
    for i in cols:
        if time:
            for j in time_part:
                df[f'{i}_{j}']=getattr(df[i].dt,j)
        for j in date_part:
            df[f'{i}_{j}']=getattr(df[i].dt,j)
    df.drop(columns=cols, inplace=True)
    return

# %%
add_datepart(df, ['timestamp'])

# %%
discrete = [var for var in df_train.columns if df_train[var].dtype!='O' and var!='price_doc' and df_train[var].nunique()<10]
continuous = [var for var in df_train.columns if df_train[var].dtype!='O' and var!='price_doc' and var not in discrete]
categorical = [var for var in df_train.columns if df_train[var].dtype=='O']

# %%
#export
def split_val(df:pd.DataFrame, val_pct:float=0.3):
    'returns `df_train` and `df_valid`'
    shuf_idx=np.random.permutation(len(df))
    train_idx, val_idx=shuf_idx[int(val_pct*len(df)):], shuf_idx[:int(val_pct*len(df))]
    return df.iloc[train_idx,:], df.iloc[val_idx,:]
    
def split_dep_col(df:pd.DataFrame, y:str):
    'returns `x` and `y`'
    return df.drop(columns=y), df.loc[:, y]
    
def train_test_split(df:pd.DataFrame, y:str=None, val_pct:float=0.3):
    ''' df 'pandas datadrame object `y` is the dependent column val_pct:=0.3'
    returns `x_train`, `y_train`, `x_valid`, `y_valid`'''
    df_train, df_val= split_val(df.copy(), val_pct)
    if y is None:
        return df_train, df_val
    else: return split_dep_col(df_train, y), split_dep_col(df_train, y)

# %%
df_train, df_val= train_test_split(df)

# %%
train_cats(df_train)
apply_cats(df_val, df_train)

# %%
x_train, y_train, nas=proc_df(df_train, 'price_doc')
x_val, y_val, nas= proc_df(df_val, 'price_doc', nas)

# %%
x_train.head()
# Out:
#        full_sq  life_sq  floor  max_floor  material  build_year  num_room  \
# id
# 15365       64     64.0    7.0       17.0       1.0      2014.0       2.0
# 20735      102    102.0   19.0        1.0       1.0      2015.0       3.0
# 11245       79     51.0    6.0        7.0       2.0      1955.0       3.0
# 13167       71      1.0   13.0       17.0       1.0      1979.0       2.0
# 6353        49     49.0    3.0       12.0       1.0      1979.0       2.0
#
#        kitch_sq  state  product_type  sub_area        area_m  raion_popul  \
# id
# 15365       1.0    1.0             2       104  2.553630e+07         4001
# 20735       1.0    1.0             2        55  6.424174e+06        51455
# 11245       8.0    2.0             1       111  6.377883e+06       101982
# 13167       1.0    1.0             2       103  6.677245e+07         9553
# 6353        6.0    2.0             2        88  3.574795e+07         2546
#
#        green_zone_part  indust_part  children_preschool  preschool_quota  \
# id
# 13167        1753          1381      1207        623          584
# 6353          337           292       322        166          156
#
#        raion_build_count_with_material_info  build_count_block  \
# id
# 15365                                 273.0               42.0
# 20735                                 167.0               36.0
# 11245                                 324.0               78.0
# 13167                                 273.0               42.0
# 6353                                  273.0               42.0
#
#        build_count_wood  build_count_frame  build_count_brick  \
# id
# 15365               0.0                0.0               67.0
# 20735               0.0                0.0               41.0
# 11245               0.0                0.0              148.0
# 13167               0.0                0.0               67.0
# 6353                0.0                0.0               67.0
#
#        build_count_monolith  build_count_panel  build_count_foam  \
# id
# 15365                   6.0               92.0               0.0
# 20735                  11.0               79.0               0.0
# 11245                   4.0               93.0               0.0
# 13167                   6.0               92.0               0.0
# 6353                    6.0               92.0               0.0
#
#        build_count_slag  build_count_mix  \
# id
# 15365               0.0              0.0
# 20735               0.0              0.0
# 11245               1.0              0.0
# 13167               0.0              0.0
# 6353                0.0              0.0
#
#        raion_build_count_with_builddate_info  build_count_before_1920  \
# id
# 15365                                  271.0                      0.0
# 20735                                  164.0                      0.0
# 11245                                  324.0                      0.0
# 13167                                  271.0                      0.0
# 6353                                   271.0                      0.0
#
#        build_count_1921-1945  build_count_1946-1970  build_count_1971-1995  \
# id
# 15365                    2.0                  135.0                   71.0
# 20735                    1.0                   99.0                   34.0
# 11245                    4.0                  231.0                   58.0
# 13167                    2.0                  135.0                   71.0
# 6353                     2.0                  135.0                   71.0
#
#        build_count_after_1995  ID_metro  metro_min_avto  metro_km_avto  \
# id
# 15365                    24.0        21        2.868785       2.295028
# 20735                    30.0       136        3.045027       1.054891
# 11245                    31.0       152        2.443090       1.954472
# 13167                    24.0        79        7.132375       6.541774
# 6353                     24.0       206       16.143444      14.338545
#
#        metro_min_walk  metro_km_walk  kindergarten_km  school_km    park_km  \
# id
# 15365       27.540341       2.295028         1.330390   1.692061   5.034657
# 20735        9.661214       0.805101         0.123641   0.348353   0.922229
# 11245       13.162476       1.096873         0.192461   0.275387   1.346983
# 13167       66.892777       5.574398         3.029289   2.883598   3.404787
# 6353       159.774903      13.314575         0.080555   7.465533  12.535910
#
#        green_zone_km  industrial_km  water_treatment_km  cemetery_km  \
# id
# 15365       0.038518       0.288225           16.953350     1.790982
# 20735       0.400504       0.219669           17.900570     3.106813
# 11245       0.000000       0.136802            8.169755     1.570948
# 13167       0.035035       0.424423            5.523638     3.359101
# 6353        0.142927       0.247327           12.817370     1.954585
#
#        incineration_km  railroad_station_walk_km  railroad_station_walk_min  \
# id
# 15365        19.538730                  4.308461                  51.701529
# 20735         6.890668                  3.288283                  39.459396
# 11245        10.000390                  0.610719                   7.328630
# 13167         8.800419                 10.745473                 128.945675
# 6353         20.370860                 15.328008                 183.936092
#
#        ID_railroad_station_walk  railroad_station_avto_km  \
# id
# 15365                      24.0                  4.308461
# 20735                      12.0                  3.538073
# 11245                      91.0                  0.610719
# 13167                      47.0                 11.572430
# 6353                       24.0                 14.720777
#
#        railroad_station_avto_min  ID_railroad_station_avto  \
# id
# 15365                   5.498317                        24
# 20735                   5.116967                        12
# 11245                   0.763399                        91
# 13167                  10.383161                        73
# 6353                   17.697994                        19
#
#        public_transport_station_km  public_transport_station_min_walk  \
# id
# 15365                     0.173000                           2.076003
# 20735                     0.172161                           2.065929
# 11245                     0.067719                           0.812625
# 13167                     1.482871                          17.794452
# 6353                      4.383929                          52.607144
#
#        water_km  water_1line    mkad_km     ttk_km  sadovoe_km  \
# id
# 15365  0.852331            1   7.595688  17.612136   20.332588
# 20735  0.509525            1   1.933489  10.651988   13.425822
# 11245  1.751644            1   4.241716   3.731862    7.590950
afe_count_1000_price_4000  cafe_count_1000_price_high  \
# id
# 15365                           0                           0
# 20735                           0                           0
# 11245                           1                           0
# 13167                           0                           0
# 6353                            0                           0
#
#        big_church_count_1000  church_count_1000  mosque_count_1000  \
# id
# 15365                      0                  0                  0
# 20735                      0                  0                  0
# 11245                      0                  2                  0
# 13167                      0                  1                  0
# 6353                       0                  0                  0
#
#        leisure_count_1000  sport_count_1000  market_count_1000  \
# id
# 15365                   0                 0                  0
# 20735                   0                 1                  0
# 11245                   0                 3                  0
# 13167                   0                 0                  0
# 6353                    0                 0                  0
#
#        green_part_1500  prom_part_1500  office_count_1500  office_sqm_1500  \
# id
# 15365            39.35            1.30                  0                0
# 20735            20.96            8.27                  2            23300
# 11245            17.86           25.14                  2             1700
# 13167            38.77            8.26                  0                0
# 6353             25.42            8.39                  0                0
#
#        trc_count_1500  trc_sqm_1500  cafe_count_1500  \
# id
# 15365               1         17000                2
# 20735               7        109440               21
# 11245               0             0                9
# 13167               0             0                0
# 6353                0             0                0
#
#        cafe_sum_1500_min_price_avg  cafe_sum_1500_max_price_avg  \
# id
# 15365                      1000.00                      1750.00
# 20735                       573.68                       973.68
# 11245                      1100.00                      1750.00
# 13167                       692.86                      1166.67
# 6353                        692.86                      1166.67
#
#        cafe_avg_price_1500  cafe_count_1500_na_price  \
# id
# 15365              1375.00                         0
# 20735               773.68                         2
# 11245              1425.00                         1
# 13167               926.73                         0
# 6353                926.73                         0
#
#        cafe_count_1500_price_500  cafe_count_1500_price_1000  \
# id
# 15365                          0                           1
# 20735                          8                           6
# 11245                          1                           1
# 13167                          0                           0
# 6353                           0                           0
#
#        cafe_count_1500_price_1500  cafe_count_1500_price_2500  \
# id
# 15365                           0                           1
# 20735                           4                           1
# 11245                           4                           1
# 13167                           0                           0
# 6353                            0                           0
#
#        cafe_count_1500_price_4000  cafe_count_1500_price_high  \
# id
# 15365                           0                           0
# 20735                           0                           0
# 11245                           1                           0
# 13167                           0                           0
# 6353                            0                           0
#
#        big_church_count_1500  church_count_1500  mosque_count_1500  \
# id
# 15365                      0                  0                  0
# 20735                      3                  0                  0
# 11245                      0                  3                  0
# 13167                      0                  1                  0
# 6353                       0                  0                  0
#
#        leisure_count_1500  sport_count_1500  market_count_1500  \
# id
# 15365                   0                 0                  0
# 20735                   0                 3                  0
# 11245                   1                10                  1
# 13167                   0                 1                  0
# 6353                    0                 0                  0
#
#        green_part_2000  prom_part_2000  office_count_2000  office_sqm_2000  \
# id
# 15365            40.87            2.23                  0                0
# 20735            23.20            5.23                  2            23300
# 11245            18.94           18.98                  3            86700
# 13167            41.84           11.87                  0                0
# 6353             45.45            5.50                  0                0
#
#        trc_count_2000  trc_sqm_2000  cafe_count_2000  \
# id
# 15365               1         17000                3
# 20735               9        231820               34
# 11245               0             0               21
# 13167               0             0                1
# 6353                0             0                0
#
#        cafe_sum_2000_min_price_avg  cafe_sum_2000_max_price_avg  \
# id
# 15365                       833.33                      1500.00
# 20735                       560.00                       966.67
# 11245                       715.00                      1200.00
# 13167                       500.00                      1000.00
# 6353                        684.34                      1157.89
#
#        cafe_avg_price_2000  cafe_count_2000_na_price  \
# id
# 15365              1166.67                         0
# 20735               763.33                         4
# 11245               957.50                         1
# 13167               750.00                         0
# 6353                920.00                         0
#
#        cafe_count_2000_price_500  cafe_count_2000_price_1000  \
# id
# 15365                          0                           2
# 20735                         11                          12
# 11245                          6                           7
# 13167                          0                           1
# 6353                           0                           0
#
#        cafe_count_2000_price_1500  cafe_count_2000_price_2500  \
# id
# 15365                           0                           1
# 20735                           6                           1
# 11245                           5                           1
# 13167                           0                           0
# 6353                            0                           0
#
#        cafe_count_2000_price_4000  cafe_count_2000_price_high  \
# id
# 15365                           0                           0
# 20735                           0                           0
# 11245                           1                           0
# 13167                           0                           0
# 6353                            0                           0
#
#        big_church_count_2000  church_count_2000  mosque_count_2000  \
# id
# 15365                      1                  3                  0
# 20735                      4                  3                  0
# 11245                      1                  4                  0
# 13167                      0                  2                  0
# 6353                       0                  1                  0
#
#        leisure_count_2000  sport_count_2000  market_count_2000  \
# id
# 15365                   0                 1                  0
# 20735                   0                 7                  0
# 11245                   1                13                  2
# 13167                   0                 1                  0
# 6353                    0                 0                  0
#
#        green_part_3000  prom_part_3000  office_count_3000  office_sqm_3000  \
#        timestamp_month  timestamp_day  timestamp_week  timestamp_dayofweek  \
# id
# 15365                2             25               9                    1
# 20735                7             10              28                    3
# 11245               10             15              42                    1
# 13167               12             17              51                    1
# 6353                 3              7              10                    3
#
#        timestamp_weekday  timestamp_quarter  timestamp_is_month_start  \
# id
# 15365                  1                  1                     False
# 20735                  3                  3                     False
# 11245                  1                  4                     False
# 13167                  1                  4                     False
# 6353                   3                  1                     False
#
#        timestamp_is_month_end  timestamp_is_year_end  life_sq_na  floor_na  \
# id
# 15365                   False                  False       False     False
# 20735                   False                  False       False     False
# 11245                   False                  False       False     False
# 13167                   False                  False       False     False
# 6353                    False                  False       False     False
#
#        max_floor_na  material_na  build_year_na  num_room_na  kitch_sq_na  \
# id
# 15365         False        False          False        False        False
# 20735         False        False          False        False        False
# 11245         False        False          False        False        False
# 13167         False        False           True        False        False
# 6353           True         True           True         True         True
#
#        state_na  preschool_quota_na  school_quota_na  hospital_beds_raion_na  \
# id
# 15365     False                True             True                    True
# 20735     False               False            False                   False
# 11245     False               False            False                    True
# 13167     False                True             True                    True
# 6353       True                True             True                    True
#
#        raion_build_count_with_material_info_na  build_count_block_na  \
# id
# 15365                                     True                  True
# 20735                                    False                 False
# 11245                                    False                 False
# 13167                                     True                  True
# 6353                                      True                  True
#
#        build_count_wood_na  build_count_frame_na  build_count_brick_na  \
# id
# 15365                 True                  True                  True
# 20735                False                 False                 False
# 11245                False                 False                 False
# 13167                 True                  True                  True
# 6353                  True                  True                  True
#
#        build_count_monolith_na  build_count_panel_na  build_count_foam_na  \
# id
# 15365                     True                  True                 True
# 20735                    False                 False                False
# 11245                    False                 False                False
# 13167                     True                  True                 True
# 6353                      True                  True                 True
#
#        build_count_slag_na  build_count_mix_na  \
# id
# 15365                 True                True
# 20735                False               False
# 11245                False               False
# 13167                 True                True
# 6353                  True                True
#
#        raion_build_count_with_builddate_info_na  build_count_before_1920_na  \
# id
# 15365                                      True                        True
# 20735                                     False                       False
# 11245                                     False                       False
# 13167                                      True                        True
# 6353                                       True                        True
#
#        build_count_1921-1945_na  build_count_1946-1970_na  \
# id
# 15365                      True                      True
# 20735                     False                     False
# 11245                     False                     False
# 13167                      True                      True
# 6353                       True                      True
#
#        build_count_1971-1995_na  build_count_after_1995_na  metro_min_walk_na  \
# id
# 15365                      True                       True              False
# 20735                     False                      False              False
# 11245                     False                      False              False
# 13167                      True                       True              False
# 6353                       True                       True              False
#
#        metro_km_walk_na  railroad_station_walk_km_na  \
# id
# 15365             False                        False
# 20735             False                        False
# 11245             False                        False
# 13167             False                        False
# 6353              False                        False
#
#        railroad_station_walk_min_na  ID_railroad_station_walk_na  \
# id
# 15365                         False                        False
# 20735                         False                        False
# 11245                         False                        False
# 13167                         False                        False
# 6353                          False                        False
#
#        cafe_sum_500_min_price_avg_na  cafe_sum_500_max_price_avg_na  \
# id
# 15365                          False                          False
# 20735                          False                          False
# 11245                          False                          False
# 13167                           True                           True
# 6353                            True                           True
#
#        cafe_avg_price_500_na  cafe_sum_1000_min_price_avg_na  \
# id
# 15365                  False                           False
# 20735                  False                           False
# 11245                  False                           False
# 13167                   True                            True
# 6353                    True                            True
#
#        cafe_sum_1000_max_price_avg_na  cafe_avg_price_1000_na  \
# id
# 15365                           False                   False
# 20735                           False                   False
# 11245                           False                   False
# 13167                            True                    True
# 6353                             True                    True
#
#        cafe_sum_1500_min_price_avg_na  cafe_sum_1500_max_price_avg_na  \
# id
# 15365                           False                           False
# 20735                           False                           False
# 11245                           False                           False
# 13167                            True                            True
# 6353                             True                            True
#
#        cafe_avg_price_1500_na  cafe_sum_2000_min_price_avg_na  \
# id
# 15365                   False                           False
# 20735                   False                           False
# 11245                   False                           False
# 13167                    True                           False
# 6353                     True                            True
#
#        cafe_sum_2000_max_price_avg_na  cafe_avg_price_2000_na  \
# id
# 15365                           False                   False
# 20735                           False                   False
# 11245                           False                   False
# 13167                           False                   False
# 6353                             True                    True
#
#        cafe_sum_3000_min_price_avg_na  cafe_sum_3000_max_price_avg_na  \
# id
# 15365                           False                           False
# 20735                           False                           False
# 11245                           False                           False
# 13167                           False                           False
# 6353                             True                            True
#
#        cafe_avg_price_3000_na  prom_part_5000_na  \
# id
# 15365                   False              False
# 20735                   False              False
# 11245                   False              False
# 13167                   False              False
# 6353                     True              False
#
#        cafe_sum_5000_min_price_avg_na  cafe_sum_5000_max_price_avg_na  \
# id
# 15365                           False                           False
# 20735                           False                           False
# 11245                           False                           False
# 13167                           False                           False
# 6353                            False                           False
#
#        cafe_avg_price_5000_na
# id
# 15365                   False
# 20735                   False
# 11245                   False
# 13167                   False
# 6353                    False

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
df.shape
# Out:
# (30471, 303)

# %%
regr=RandomForestRegressor(max_depth=6, max_samples=5000, n_jobs=-1, verbose=10, oob_score=True, min_samples_split=3)

# %%
param_grid={'n_estimators':list(range(100, 500, 100)),
            'max_depth':list(range(5, 15,2)), 
            'min_samples_split':[50, 25, 10] 
            }

# %%
regr=GridSearchCV(RandomForestRegressor(max_samples=1000,
                                        n_jobs=-1,
                                        oob_score=True),
                  param_grid=param_grid, n_jobs=-1,
                 )

# %%
regr.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-a86aeec44655> in <module>
# ----> 1 regr.fit(x_train, y_train)
#
# D:\narain\Anaconda3\envs\dl\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# D:\narain\Anaconda3\envs\dl\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# D:\narain\Anaconda3\envs\dl\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     687                                for parameters, (train, test)
#     688                                in product(candidate_params,
# --> 689                                           cv.split(X, y, groups)))
#     690
#     691                 if len(out) < 1:
#
# D:\narain\Anaconda3\envs\dl\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# D:\narain\Anaconda3\envs\dl\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# D:\narain\Anaconda3\envs\dl\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# D:\narain\Anaconda3\envs\dl\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# D:\narain\Anaconda3\envs\dl\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# D:\narain\Anaconda3\envs\dl\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# D:\narain\Anaconda3\envs\dl\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# D:\narain\Anaconda3\envs\dl\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     513             estimator.fit(X_train, **fit_params)
#     514         else:
# --> 515             estimator.fit(X_train, y_train, **fit_params)
#     516
#     517     except Exception as e:
#
# D:\narain\Anaconda3\envs\dl\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     387
#     388         if self.oob_score:
# --> 389             self._set_oob_score(X, y)
#     390
#     391         # Decapsulate classes_ attributes
#
# D:\narain\Anaconda3\envs\dl\lib\site-packages\sklearn\ensemble\_forest.py in _set_oob_score(self, X, y)
#     804                 estimator.random_state, n_samples, n_samples_bootstrap)
#     805             p_estimator = estimator.predict(
# --> 806                 X[unsampled_indices, :], check_input=False)
#     807
#     808             if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
music_path
# Out:
# WindowsPath('e:/music/down/kuthu/OK Kanmani - Kaara Aattakkaara Video _ A.R. Rahman, Mani Ratnam-m-pK_pf-anc')

# %%
music_path=Path(r'e:\music\down\kuthu')
# !f'{list(music_path.iterdir())[11]}'
# Out:
# The filename, directory name, or volume label syntax is incorrect.

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV

# %%
mean_squared_error(regr.predict(x_val), y_val)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  45 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  69 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  82 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  96 out of 100 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# 8246548891350.338

# %%
mean_squared_error(regr.predict(x_train), y_train)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  45 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  69 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  82 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  96 out of 100 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# 7409864722939.515
