# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
from PIL import Image, ImageFilter
from pathlib import Path
from exp.nb_05 import *
import PIL

# %%
path=Path(r'E:\images\wallpaper')
c=L(path.iterdir())

# %%
c[2]
# Out:
# WindowsPath('E:/images/wallpaper/ana-de-armas-7360x4912-4k-8k-13655.jpg')

# %%
img=Image.open(c[2])
img.show()

# %%
img.height/15, img.width/15
# Out:
# (327.46666666666664, 490.6666666666667)

# %%
def img_factor(img, factor, method=Image.BILINEAR):
    return img.resize((int(img.width/factor), int(img.height/factor)), method)

# %%
img_factor(img, 15, Image.BILINEAR)
# Out:
# <PIL.Image.Image image mode=RGB size=490x327 at 0x1B80EFA1588>

# %%
#export
def show_image(im, figsize=(3,3)):
    plt.figure(figsize=figsize)
    plt.axis('off')
    plt.imshow(im)

# %%
img_factor(img, 10)
# Out:
# <PIL.Image.Image image mode=RGB size=736x491 at 0x1B80F3F3088>

# %%
img_1=img.filter(ImageFilter.BLUR)
img_factor(img_1, 10)
# Out:
# <PIL.Image.Image image mode=RGB size=736x491 at 0x1B80EC20EC8>

# %%
img_1=img.filter(ImageFilter.MinFilter(23))
img_factor(img_1, 10)
# Out:
# <PIL.Image.Image image mode=RGB size=736x491 at 0x1B80F408408>

# %%
import albumentations as A
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-73-7c2496d7954d> in <module>
# ----> 1 import albumentations as A
#
# ModuleNotFoundError: No module named 'albumentations'
